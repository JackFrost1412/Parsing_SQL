# %%
import re

def remove_comments(sql):
    # Loại bỏ các comment kiểu -- đến cuối dòng
    sql = re.sub(r'--.*', '', sql)
    # Loại bỏ các comment kiểu /* ... */
    sql = re.sub(r'/\*.*?\*/', '', sql, flags=re.DOTALL)
    return sql

def extract_jobs_and_sql(dsx_content):
    # Tìm tất cả các tên job trong DSJOB
    job_names = re.findall(r'BEGIN DSJOB.*?Identifier "(.*?)"', dsx_content, re.DOTALL)

    # Tìm tất cả các đoạn CDATA chứa câu truy vấn SQL
    sql_queries = re.findall(r'<!\[CDATA\[(.*?)\]\]>', dsx_content, re.DOTALL | re.IGNORECASE)

    cleaned_sql_queries = []
    for query in sql_queries:
        # Loại bỏ khoảng trắng thừa ở đầu và cuối chuỗi
        query = query.strip()

        # Loại bỏ comment trong câu truy vấn
        query = remove_comments(query)
        
        # Chỉ lấy những câu truy vấn bắt đầu bằng từ khóa SQL chính xác (ví dụ: SELECT, UPDATE, INSERT INTO, DELETE FROM)
        sql_keywords = ['SELECT', 'UPDATE', 'INSERT INTO', 'DELETE FROM']
        for keyword in sql_keywords:
            if query.upper().startswith(keyword):
                # Loại bỏ phần trước từ khóa và chỉ giữ lại câu truy vấn
                cleaned_query = re.sub(rf'^.*?\b{keyword}\b', keyword, query, flags=re.DOTALL)
                # Cắt bỏ bất kỳ phần nào sau dấu chấm phẩy đầu tiên
                cleaned_query = re.split(r';', cleaned_query)[0]

                # Thêm dấu chấm phẩy vào cuối câu nếu chưa có
                if not cleaned_query.endswith(';'):
                    cleaned_query += ';'

                cleaned_sql_queries.append(cleaned_query)
                break

    return job_names, cleaned_sql_queries

# Đọc nội dung của file .dsx
with open('FNC_SVC_AR_FCT_FA.dsx', 'r', encoding='utf-8') as file:
    dsx_content = file.read()

# Gọi hàm để trích xuất tên job và các truy vấn SQL
job_names, sql_queries = extract_jobs_and_sql(dsx_content)

# Hiển thị các job và các truy vấn SQL
print("Job Names:")
for job in job_names:
    print(job)

print("\nSQL Queries:")
for query in sql_queries:
    print(query)
# Out:
# Job Names:
# PAR_DMT_FNC_SVC_AR_ANL_FCT_FA_Ins
# PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_CHG_TruncIns
# PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_CST_PD_TruncIns
# PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_LST_DY_TruncIns
# PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_TruncIns
# PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
#
# SQL Queries:
# SELECT
# 	AC_AR_DIM.AC_AR_DIM_ID					AC_AR_DIM_ID
# 	,CST_DIM.CST_DIM_ID						CST_DIM_ID
# 	,LOAN_PPS_DIM.LOAN_PPS_DIM_ID			LOAN_PPS_DIM_ID
# 	,PD_DIM.PD_DIM_ID						PD_DIM_ID
# 	,RLTNP_OFCR.EMPE_DIM_ID					RLTNP_OFCR_DIM_ID
# 	,IDY_DIM.IDY_DIM_ID						IDY_DIM_ID
# 	,LDGR_ACG_DIM.LDGR_ACG_DIM_ID			LDGR_ACG_DIM_ID
# 	,TERM_DIM.GRP_DIM_ID					TERM_DIM_ID
# 	,ADJ_OU.OU_DIM_ID						ADJ_OU_DIM_ID
# 	,ADJ_CCY.CCY_DIM_ID						ADJ_CCY_DIM_ID
# 	,ADJ_LOB.LOB_DIM_ID						ADJ_LOB_DIM_ID
# 	,CST_FNC_ST_DIM.FNC_ST_DIM_ID			CST_FNC_ST_DIM_ID
# 	,ADJ_FNC_ST_DIM.FNC_ST_DIM_ID			ADJ_FNC_ST_DIM_ID
# 	,MIS_ADJ_FNC_ST_DIM.FNC_ST_DIM_ID		MIS_ADJ_FNC_ST_DIM_ID
# 	,FNL_FNC_ST_DIM.FNC_ST_DIM_ID			FNL_FNC_ST_DIM_ID
# 	,FNC_ST_TP_DIM.GRP_DIM_ID				FNC_ST_TP_DIM_ID
# 	,CG_SEGMENT_DIM.CG_SEG_DIM_ID			CG_SEG_DIM_ID
# 	,MSEG_DIM.MSEG_DIM_ID					MSEG_DIM_ID
# 	,T.CLS_BAL_FCY
# 	,T.CLS_BAL_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'IW')
# 				THEN T.CLS_BAL_FCY
# 		ELSE nvl(lst.CLS_BAL_WTD_FCY, 0) + T.CLS_BAL_FCY
# 	END													CLS_BAL_WTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'IW')
# 				THEN T.CLS_BAL_LCY
# 		ELSE nvl(lst.CLS_BAL_WTD_LCY, 0) + T.CLS_BAL_LCY
# 	END 												CLS_BAL_WTD_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN T.CLS_BAL_FCY
# 		ELSE nvl(lst.CLS_BAL_MTD_FCY, 0) + T.CLS_BAL_FCY
# 	END 												CLS_BAL_MTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN T.CLS_BAL_LCY
# 		ELSE nvl(lst.CLS_BAL_MTD_LCY, 0) + T.CLS_BAL_LCY
# 	END 												CLS_BAL_MTD_LCY
# 	,T.LQD_AMT_FCY
# 	,T.LQD_AMT_LCY
# 	,T.DSBR_AMT_FCY
# 	,T.DSBR_AMT_LCY
#
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN T.DSBR_AMT_LCY
# 		ELSE nvl(lst.DSBR_AMT_MTD_LCY, 0) + T.DSBR_AMT_LCY
# 	END 									DSBR_AMT_MTD_LCY
# 	,T.PREPYMT_AMT_FCY
# 	,T.PREPYMT_AMT_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN T.PREPYMT_AMT_FCY
# 		ELSE nvl(lst.PREPYMT_AMT_MTD_FCY, 0) + T.PREPYMT_AMT_FCY
# 	END 												PREPYMT_AMT_MTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN T.PREPYMT_AMT_LCY
# 		ELSE nvl(lst.PREPYMT_AMT_MTD_LCY, 0) + T.PREPYMT_AMT_LCY
# 	END     											PREPYMT_AMT_MTD_LCY
# 	,													T.PY_OFF_BFR_DUE_DT_F
# 	,													T.INT_RATE
# 	,#pdate#											CDR_DT_DIM_ID
# 	,decode(T.MUD, 'OD', 0, AC_AR_DIM.TERM_IN_MO)		TERM_IN_MO
# 	,SRO_DIM.SRO_DIM_ID									SRO_DIM_ID
# 	,T.PB_MISCODE_F
# 	,T.PB_CST_F
# 	,PYMTC_DIM.PYMTC_DIM_ID								PYMTC_DIM_ID
# 	,T.MUD
# 	,LOB.LOB_DIM_ID										LOB_DIM_ID
# 	,OU.OU_DIM_ID										OU_DIM_ID
# 	,CIC_FNC_ST_DIM.FNC_ST_DIM_ID						CIC_FNC_ST_DIM_ID
# 	,CCY.CCY_DIM_ID										CCY_DIM_ID
# 	,FNC_SVC_MINI.FNC_SVC_AR_MINI_DIM_ID				FNC_SVC_AR_MINI_DIM_ID
# 	,OVRL_CST.FNC_ST_DIM_ID								OVRL_CST_FNC_ST_DIM_ID
# 	,OVRL_MIS_ADJ.FNC_ST_DIM_ID							OVRL_MIS_ADJ_FNC_ST_DIM_ID
# 	,OVRL_FNL.FNC_ST_DIM_ID								OVRL_FNL_FNC_ST_DIM_ID
# 	,T.ORIG_CLS_BAL_FCY
# 	,T.ORIG_CLS_BAL_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN T.ORIG_CLS_BAL_FCY
# 		ELSE nvl(lst.ORIG_CLS_BAL_MTD_FCY, 0) + T.ORIG_CLS_BAL_FCY
# 	END 												ORIG_CLS_BAL_MTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN T.ORIG_CLS_BAL_LCY
# 		ELSE nvl(lst.ORIG_CLS_BAL_MTD_LCY, 0) + T.ORIG_CLS_BAL_LCY
# 	END 												ORIG_CLS_BAL_MTD_LCY
# 	,PD_DIM.PD_CODE||FNC_SVC_MINI.DTL_PD_CODE			CMB_PD_CODE
#
# 	,ORIG_PD.PD_DIM_ID									ORIG_PD_DIM_ID
# 	,MID1_OU.OU_DIM_ID									MIS1_OU_DIM_ID
# 	,NVL(PD_DTL.PD_DTL_GRP_DIM_ID, PD_DTL1.PD_DTL_GRP_DIM_ID)	PD_DTL_GRP_DIM_ID
#
#                 ,T.FEE_INCM_LCY
#                 ,T.TOT_LMT_AMT
#
#
#                 ,T.NOD_PAST_DUE
#                 ,T.PNP_ARS TOT_PAST_DUE_PNP
#                 ,T.INT_ARS TOT_PAST_DUE_INT
#                 ,T.CLS_UTLZ_AMT_FCY
#                 ,T.PNP_DUE_AMT
#                 ,T.INT_DUE_AMT
#                 ,T.DLQ_CNT
# ,T.TOT_DSBR_AMT_FCY
# ,AC_AR_MINI.AC_AR_MINI_DIM_ID
# ,T.TOT_AVL_LMT_AMT
# ,T.INTERIM_INT
# ,ORIG_OU.OU_DIM_ID ORIG_OU_DIM_ID
# ,CST_SEG_MINI_DIM.CST_SEG_MINI_DIM_ID
# FROM TWT_FNC_SVC_AR_ANL_FCT_FA T
# INNER JOIN AC_AR_DIM 					ON AC_AR_DIM.AC_AR_ID = T.AC_AR_ID AND AC_AR_DIM.EFF_DT <= #pdate# AND AC_AR_DIM.END_DT > #pdate#
# LEFT JOIN TWT_FCA_ANL_FCT_FA_LST_DY LST ON AC_AR_DIM.AC_AR_ID = LST.AC_AR_ID AND LST.CDR_DT_DIM_ID = to_number(to_char(to_date(#pdate#, 'yyyymmdd')-1, 'yyyymmdd'))
# LEFT JOIN FNC_SVC_AR_MINI_DIM FNC_SVC_MINI	ON FNC_SVC_MINI.FNC_SVC_AR_ID = T.AC_AR_ID AND FNC_SVC_MINI.EFF_DT <= #pdate# AND FNC_SVC_MINI.END_DT > #pdate#
#
# LEFT JOIN TWT_FNC_SVC_AR_FCT_FA_CST_PD PD_CST ON T.AC_AR_ID = PD_CST.AC_AR_ID
# LEFT JOIN TWT_PUB_AC_AR_INFO TB_IF ON TB_IF.AR_ID = T.AC_AR_ID
# LEFT JOIN AC_AR_MINI_DIM AC_AR_MINI ON AC_AR_MINI.EFF_DT<=#pdate# AND AC_AR_MINI.END_DT>#pdate#
# 	AND NVL(PD_CST.GL_FNC_ST_CODE, 'NULL') = AC_AR_MINI.AR_FNC_ST
# 	AND NVL(PD_CST.CST_PD_FNC_ST_CODE, 'NULL') = AC_AR_MINI.CST_PD_FNC_ST_CODE
# 	AND nvl(TB_IF.CST_INCM_F,'N') = AC_AR_MINI.CST_INCM_F
#
# LEFT JOIN CST_DIM 						ON CST_DIM.CST_ID = T.CST_ID AND CST_DIM.EFF_DT <= #pdate# AND CST_DIM.END_DT > #pdate#
# LEFT JOIN LOAN_PPS_DIM 					ON LOAN_PPS_DIM.PPS_CODE = T.LOAN_PPS_CODE AND LOAN_PPS_DIM.EFF_DT <= #pdate# AND LOAN_PPS_DIM.END_DT > #pdate# AND LOAN_PPS_DIM.PPS_TP = 'MUC DICH VAY'
# LEFT JOIN PD_DIM 						ON PD_DIM.PD_CODE = T.PD_CODE AND PD_DIM.EFF_DT <= #pdate# AND PD_DIM.END_DT > #pdate#
# 										AND CASE WHEN T.MUD IN ('LN', 'OD') THEN 'FCC' ELSE 'SMV' END = SUBSTR(PD_DIM.SRC_STM_CODE, 1, INSTR(PD_DIM.SRC_STM_CODE, '.')-1)
# LEFT JOIN PD_DIM ORIG_PD 				ON ORIG_PD.PD_CODE = T.ORIG_PD_CODE AND ORIG_PD.EFF_DT <= #pdate# AND ORIG_PD.END_DT > #pdate#
# 										AND CASE WHEN T.MUD IN ('LN', 'OD') THEN 'FCC' ELSE 'SMV' END = SUBSTR(ORIG_PD.SRC_STM_CODE, 1, INSTR(ORIG_PD.SRC_STM_CODE, '.')-1)
# LEFT JOIN EMPE_DIM RLTNP_OFCR 			ON RLTNP_OFCR.EMPE_ID = T.RLTNP_OFCR_ID AND RLTNP_OFCR.EFF_DT <= #pdate# AND RLTNP_OFCR.END_DT > #pdate#
# LEFT JOIN IDY_DIM 						ON IDY_DIM.IDY_SHRT_CODE = T.IDY_CODE AND IDY_DIM.EFF_DT <= #pdate# AND IDY_DIM.END_DT > #pdate# AND SUBSTR(IDY_DIM.IDY_CODE, 1, INSTR(IDY_DIM.IDY_CODE, '.')-1) = 'NGANH_NGHE_KINH_TE_SBV'
# LEFT JOIN LDGR_ACG_DIM 					ON LDGR_ACG_DIM.LDGR_ACG_ID = T.LDGR_ACG_ID AND LDGR_ACG_DIM.EFF_DT <= #pdate# AND LDGR_ACG_DIM.END_DT > #pdate#
# LEFT JOIN GRP_DIM TERM_DIM				ON TERM_DIM.GRP_CODE = decode(T.MUD, 'OD', 'S', CASE WHEN AC_AR_DIM.TERM_IN_MO <= 12 THEN 'S' WHEN AC_AR_DIM.TERM_IN_MO <= 60 THEN 'M' ELSE 'L' END)
# 										AND TERM_DIM.PRN_GRP_CODE = 'TERM_SEG_TP' AND TERM_DIM.EFF_DT <= #pdate# AND TERM_DIM.END_DT > #pdate#
# LEFT JOIN OU_DIM ADJ_OU 				ON ADJ_OU.CODE = T.ADJ_OU_CODE AND ADJ_OU.EFF_DT <= #pdate# AND ADJ_OU.END_DT > #pdate#
# LEFT JOIN OU_DIM OU						ON OU.CODE = T.OU_CODE AND OU.EFF_DT <= #pdate# AND OU.END_DT > #pdate#
# LEFT JOIN OU_DIM MID1_OU				ON MID1_OU.CODE = T.MIS1_OU_CODE AND MID1_OU.EFF_DT <= #pdate# AND MID1_OU.END_DT > #pdate#
# LEFT JOIN CCY_DIM ADJ_CCY 				ON ADJ_CCY.ALPB_CCY_CODE = T.ADJ_CCY_CODE AND ADJ_CCY.EFF_DT <= #pdate# AND ADJ_CCY.END_DT > #pdate#
# LEFT JOIN CCY_DIM CCY 					ON CCY.ALPB_CCY_CODE = T.CCY_CODE AND CCY.EFF_DT <= #pdate# AND CCY.END_DT > #pdate#
# LEFT JOIN LOB_DIM ADJ_LOB				ON ADJ_LOB.LOB_CODE = T.ADJ_LOB_CODE
# LEFT JOIN LOB_DIM LOB					ON LOB.LOB_CODE = T.LOB_CODE
#
# LEFT JOIN PD_DTL_GRP_DIM PD_DTL			ON PD_DTL.LINE = ADJ_LOB.LOB_CODE AND PD_DTL.MAP_SPCT = PD_DIM.PD_CODE||FNC_SVC_MINI.DTL_PD_CODE
# 										AND PD_DTL.EFF_DT <= #pdate# AND PD_DTL.END_DT > #pdate#
# LEFT JOIN PD_DTL_GRP_DIM PD_DTL1			ON PD_DTL1.LINE = ADJ_LOB.LOB_CODE AND PD_DTL1.MAP_SPCT = ORIG_PD.PD_CODE
# 										AND PD_DTL1.EFF_DT <= #pdate# AND PD_DTL1.END_DT > #pdate#
#
# LEFT JOIN FNC_ST_DIM ADJ_FNC_ST_DIM 	ON ADJ_FNC_ST_DIM.FNC_ST_CODE = T.ADJ_FNC_ST_CODE AND ADJ_FNC_ST_DIM.EFF_DT <= #pdate# AND ADJ_FNC_ST_DIM.END_DT > #pdate#
# LEFT JOIN FNC_ST_DIM CST_FNC_ST_DIM 	ON CST_FNC_ST_DIM.FNC_ST_CODE = T.CST_FNC_ST_CODE AND CST_FNC_ST_DIM.EFF_DT <= #pdate# AND CST_FNC_ST_DIM.END_DT > #pdate#
# LEFT JOIN FNC_ST_DIM MIS_ADJ_FNC_ST_DIM ON MIS_ADJ_FNC_ST_DIM.FNC_ST_CODE = T.MIS_ADJ_FNC_ST_CODE AND MIS_ADJ_FNC_ST_DIM.EFF_DT <= #pdate# AND MIS_ADJ_FNC_ST_DIM.END_DT > #pdate#
# LEFT JOIN FNC_ST_DIM FNL_FNC_ST_DIM 	ON FNL_FNC_ST_DIM.FNC_ST_CODE = T.FNL_FNC_ST_CODE AND FNL_FNC_ST_DIM.EFF_DT <= #pdate# AND FNL_FNC_ST_DIM.END_DT > #pdate#
# LEFT JOIN FNC_ST_DIM OVRL_CST 			ON OVRL_CST.FNC_ST_CODE = T.OVRL_CST_FNC_ST_CODE AND OVRL_CST.EFF_DT <= #pdate# AND OVRL_CST.END_DT > #pdate#
# LEFT JOIN FNC_ST_DIM OVRL_MIS_ADJ 		ON OVRL_MIS_ADJ.FNC_ST_CODE = T.OVRL_MIS_ADJ_FNC_ST_CODE AND OVRL_MIS_ADJ.EFF_DT <= #pdate# AND OVRL_MIS_ADJ.END_DT > #pdate#
# LEFT JOIN FNC_ST_DIM OVRL_FNL 			ON OVRL_FNL.FNC_ST_CODE = T.OVRL_FNL_FNC_ST_CODE AND OVRL_FNL.EFF_DT <= #pdate# AND OVRL_FNL.END_DT > #pdate#
# LEFT JOIN FNC_ST_DIM CIC_FNC_ST_DIM 	ON CIC_FNC_ST_DIM.FNC_ST_CODE = T.CIC_FNC_ST_CODE AND CIC_FNC_ST_DIM.EFF_DT <= #pdate# AND CIC_FNC_ST_DIM.END_DT > #pdate#
# LEFT JOIN GRP_DIM FNC_ST_TP_DIM 		ON FNC_ST_TP_DIM.GRP_CODE = T.FNC_ST_TP_CODE AND FNC_ST_TP_DIM.EFF_DT <= #pdate# AND FNC_ST_TP_DIM.END_DT > #pdate#
# LEFT JOIN CG_SEG_DIM CG_SEGMENT_DIM 	ON CG_SEGMENT_DIM.CG_SEG_ID = T.CG_SEG AND CG_SEGMENT_DIM.EFF_DT <= #pdate# AND CG_SEGMENT_DIM.END_DT > #pdate#
# LEFT JOIN MSEG_DIM 						ON MSEG_DIM.MSEG_ID = T.MSEG AND MSEG_DIM.EFF_DT <= #pdate# AND MSEG_DIM.END_DT > #pdate#
# LEFT JOIN SRO_DIM 						ON SRO_DIM.SRO_CODE = T.SRO_CODE AND SRO_DIM.EFF_DT <= #pdate# AND SRO_DIM.END_DT > #pdate#
# LEFT JOIN PYMTC_DIM 					ON PYMTC_DIM.PYMTC_ID = T.PYMT_CARD_ID AND PYMTC_DIM.EFF_DT <= #pdate# AND PYMTC_DIM.END_DT > #pdate#
#
# LEFT JOIN OU_DIM ORIG_OU ON ORIG_OU.CODE = T.RPRG_OU_CODE AND ORIG_OU.EFF_DT <= #pdate# AND ORIG_OU.END_DT > #pdate#
# LEFT JOIN TWT_PUB_CST_INFO ON TWT_PUB_CST_INFO.IP_ID = T.CST_ID
# LEFT JOIN CST_SEG_MINI_DIM ON
# 	TWT_PUB_CST_INFO.LCS = CST_SEG_MINI_DIM.LCS
# 	AND TWT_PUB_CST_INFO.FN_ST = CST_SEG_MINI_DIM.FNC_ST_CODE
# 	AND TWT_PUB_CST_INFO.CLT_F = CST_SEG_MINI_DIM.CLT_F
#
# UNION ALL
# SELECT
# 	LST.AC_AR_DIM_ID
# 	,LST.CST_DIM_ID
# 	,LST.LOAN_PPS_DIM_ID
# 	,LST.PD_DIM_ID
# 	,LST.RLTNP_OFCR_DIM_ID
# 	,LST.IDY_DIM_ID
# 	,LST.LDGR_ACG_DIM_ID
# 	,LST.TERM_DIM_ID
# 	,LST.ADJ_OU_DIM_ID
# 	,LST.ADJ_CCY_DIM_ID
# 	,LST.ADJ_LOB_DIM_ID
# 	,LST.CST_FNC_ST_DIM_ID
# 	,LST.ADJ_FNC_ST_DIM_ID
# 	,LST.MIS_ADJ_FNC_ST_DIM_ID
# 	,LST.FNL_FNC_ST_DIM_ID
# 	,LST.FNC_ST_TP_DIM_ID
# 	,LST.CG_SEG_DIM_ID
# 	,LST.MSEG_DIM_ID
# 	,0 CLS_BAL_FCY
# 	,0 CLS_BAL_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'IW')
# 				THEN 0
# 		ELSE LST.CLS_BAL_WTD_FCY END CLS_BAL_WTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'IW')
# 				THEN 0
# 		ELSE LST.CLS_BAL_WTD_LCY END CLS_BAL_WTD_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN 0
# 		ELSE LST.CLS_BAL_MTD_FCY END CLS_BAL_MTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN 0
# 		ELSE LST.CLS_BAL_MTD_LCY END CLS_BAL_MTD_LCY
# 	,0 LQD_AMT_FCY
# 	,0 LQD_AMT_LCY
# 	,0 DSBR_AMT_FCY
# 	,0 DSBR_AMT_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN 0
# 		ELSE LST.DSBR_AMT_MTD_LCY END DSBR_AMT_MTD_LCY
# 	,0 PREPYMT_AMT_FCY
# 	,0 PREPYMT_AMT_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN 0
# 		ELSE LST.PREPYMT_AMT_MTD_FCY END PREPYMT_AMT_MTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN 0
# 		ELSE LST.PREPYMT_AMT_MTD_LCY END PREPYMT_AMT_MTD_LCY
# 	,LST.PY_OFF_BFR_DUE_DT_F
# 	,LST.INT_RATE
# 	,LST.CDR_DT_DIM_ID
# 	,LST.TERM_IN_MO
# 	,LST.SRO_DIM_ID
# 	,LST.PB_MISCODE_F
# 	,LST.PB_CST_F
# 	,LST.PYMTC_DIM_ID
# 	,LST.MUD
# 	,LST.LOB_DIM_ID
# 	,LST.OU_DIM_ID
# 	,LST.CIC_FNC_ST_DIM_ID
# 	,LST.CCY_DIM_ID
# 	,LST.FNC_SVC_AR_MINI_DIM_ID
# 	,LST.OVRL_CST_FNC_ST_DIM_ID
# 	,LST.OVRL_MIS_ADJ_FNC_ST_DIM_ID
# 	,LST.OVRL_FNL_FNC_ST_DIM_ID
# 	,0 ORIG_CLS_BAL_FCY
# 	,0 ORIG_CLS_BAL_LCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN 0
# 		ELSE LST.ORIG_CLS_BAL_MTD_FCY END ORIG_CLS_BAL_MTD_FCY
# 	,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, 'YYYYMMDD'), 'MONTH')
# 				THEN 0
# 		ELSE LST.ORIG_CLS_BAL_MTD_LCY END ORIG_CLS_BAL_MTD_LCY
# 	,LST.CMB_PD_CODE
# 	,LST.ORIG_PD_DIM_ID
# 	,LST.MIS1_OU_DIM_ID
# 	,LST.PD_DTL_GRP_DIM_ID
# 	,0 FEE_INCM_LCY
# 	,0 TOT_LMT_AMT
# 	,0 NOD_PAST_DUE
# 	,0 TOT_PAST_DUE_PNP
# 	,0 TOT_PAST_DUE_INT
# 	,0 CLS_UTLZ_AMT_FCY
# 	,0 PNP_DUE_AMT
# 	,0 INT_DUE_AMT
# 	,0 DLQ_CNT
# 	,0 TOT_DSBR_AMT_FCY
# 	,LST.AC_AR_MINI_DIM_ID
# 	,0 TOT_AVL_LMT_AMT
# 	,0 INTERIM_INT
# 	,LST.ORIG_OU_DIM_ID
# 	,LST.CST_SEG_MINI_DIM_ID
# FROM FNC_SVC_AR_ANL_FCT_FA LST
# JOIN AC_AR_DIM AC ON AC.AC_AR_DIM_ID = LST.AC_AR_DIM_ID
# WHERE LST.CDR_DT_DIM_ID = to_number(to_char(to_date(#pdate#, 'yyyymmdd') - 1, 'yyyymmdd'))
# 	AND NOT EXISTS (
# 		SELECT 1
# 		FROM TWT_FNC_SVC_AR_ANL_FCT_FA T
# 		WHERE T.AC_AR_ID = AC.AC_AR_ID
# 		);
# Delete from FNC_SVC_AR_ANL_FCT_FA where CDR_DT_DIM_ID = #pdate#;
# SELECT
# 	AC_AR.AC_AR_ID
# 	,PD_AR.PD_ID
# 	,COALESCE(LN.LAST_EFF_DT, OD.LAST_EFF_DT, CARD.LAST_EFF_DT)							LAST_EFF_DT
# 	,COALESCE(LN.ADJ_BAL, OD.ADJ_BAL, CARD.ADJ_BAL)										ADJ_BAL
# 	,AR.UNQ_ID_IN_SRC_STM																AR_UNQ_ID
# 	,CASE WHEN
# 		CASE WHEN LN.AR_ID IS NOT NULL THEN 'LN'
# 			WHEN OD.AR_ID IS NOT NULL THEN 'OD'
# 			WHEN CARD.AR_ID IS NOT NULL THEN 'CARD'
# 		END IN ('OD', 'CARD') THEN PD_AR.PRM_CST_ID
# 	ELSE NULL END																		CST_ID
# 	,CASE WHEN LN.AR_ID IS NOT NULL THEN 'LN'
# 		WHEN OD.AR_ID IS NOT NULL THEN 'OD'
# 		WHEN CARD.AR_ID IS NOT NULL THEN 'CARD'
# 	END																					MUD
# 	,PD.UNQ_ID_IN_SRC_STM																PD_CODE
# 	,CCY.CCY_CODE																		CCY_CODE
# 	,CARD.CARD_ID
# 	,CARD_AR.SALE_EMPE_ID
# 	,COALESCE(LN.ACG_STC_ITM_ID, OD.ACG_STC_ITM_ID, AU.ACG_STC_ITM_ID)					ACG_STC_ITM_ID
# 	,NVL(MAP.MA_NHOM_NO, 'NORM') 														CARD_AR_FNC_ST_TP_CODE
# 	,RPRG_OU.UNQ_ID_IN_SRC_STM															RPRG_OU_CODE
# 	,LN.LN_FNC_ST_CODE
# FROM AC_AR
# LEFT JOIN TWT_CUST_LOAN_FA LN ON AC_AR.AC_AR_ID = LN.AR_ID
# LEFT JOIN TWT_CST_OD_OPEN OD	ON AC_AR.AC_AR_ID = OD.AR_ID
# LEFT JOIN TWT_CARD_OPEN CARD	ON AC_AR.AC_AR_ID = CARD.AR_ID
# LEFT JOIN AR           			ON AC_AR.AC_AR_ID = AR.AR_ID
# LEFT JOIN IP RPRG_OU			ON RPRG_OU.IP_ID = AR.RPRG_OU_ID
# LEFT JOIN PD_AR         		ON AC_AR.AC_AR_ID = PD_AR.PD_AR_ID
# LEFT JOIN PD 					ON PD.PD_ID = PD_AR.PD_ID
# LEFT JOIN CCY 					ON CCY.CCY_ID = AR.DNMN_CCY_ID
#
# LEFT JOIN AR CARD_AR			ON CARD_AR.AR_ID = CARD.CARD_ID
# LEFT JOIN TMP_AR_X_AU AU		ON AU.AR_ID = CARD.AR_ID AND AU.AR_X_AU_TP_CODE = 'AR_X_DR_AU'
# LEFT JOIN CC_AR_SMY SMY			ON CARD.AR_ID = SMY.CC_AR_ID
# 	AND smy.MSR_PRD_ID = #pDate#
# LEFT JOIN EXT_XLS_MAP_NHOMNO_THE_TDY MAP ON SMY.NOD_PAST_DUE < NVL(MAP.HIGH_VAL, SMY.NOD_PAST_DUE + 1)
# 	AND SMY.NOD_PAST_DUE >= NVL(MAP.LOW_VAL, SMY.NOD_PAST_DUE)
# 	AND SMY.NOD_PAST_DUE >= NVL(MAP.LOW_VAL, SMY.NOD_PAST_DUE)
# WHERE AC_AR.SRC_STM_ID IN ('3FBF9A0B41B2BE2CA30C68E2B64D00A7','85425375A0630AA9C05A16D7D3420345','D461039F96DF94CBDFD7BC02909C9521')
# AND COALESCE(LN.AR_ID,OD.AR_ID,CARD.AR_ID) IS NOT NULL;
# SELECT A.AC_AR_ID
# 	,A.CST_ID
# 	,A.PD_CODE
# 	,A.PD_SRC_STM_CODE
# 	,A.ADJ_FNC_ST_CODE GL_FNC_ST_CODE
# 	,MAX(ADJ_FNC_ST_CODE) OVER(PARTITION BY A.CST_ID, A.PD_CODE, A.PD_SRC_STM_CODE) CST_PD_FNC_ST
# FROM TWT_FNC_SVC_AR_FCT_FA A;
# SELECT
# 	AC_AR_DIM.AC_AR_ID
# 	,CLS_BAL_WTD_FCY
# 	,CLS_BAL_WTD_LCY
# 	,CLS_BAL_MTD_FCY
# 	,CLS_BAL_MTD_LCY
# 	,PREPYMT_AMT_MTD_FCY
# 	,PREPYMT_AMT_MTD_LCY
# 	,CDR_DT_DIM_ID
# 	,DSBR_AMT_MTD_LCY
# 	,ORIG_CLS_BAL_MTD_FCY
# 	,ORIG_CLS_BAL_MTD_LCY
# FROM FNC_SVC_AR_ANL_FCT_FA FCT
# LEFT JOIN AC_AR_DIM ON AC_AR_DIM.AC_AR_DIM_ID = FCT.AC_AR_DIM_ID
# WHERE FCT.CDR_DT_DIM_ID = to_number(to_char(to_date(#pDate#, 'yyyymmdd')-1, 'yyyymmdd'))
# AND FCT.SRO_DIM_ID = 7;
# SELECT ARF.AR_ID, ARF.EFF_DT, ARF.END_DT, CD.CL_CODE
# 	FROM AR_FNC_ST ARF
# 	LEFT JOIN CV CD ON CD.CL_ID = ARF.AR_FNC_ST_TP_ID
#       WHERE ARF.AR_FNC_ST_SCM_ID = 'FF2F2563FA9BFED792EDC3A35EFDEE92') ARF ON AC_AR_ID = ARF.AR_ID
# 	  AND ARF.EFF_DT <= LAST_EFF_DT AND ARF.END_DT > LAST_EFF_DT ;
# SELECT AC_AR.AC_AR_ID
# 	,nvl(max(decode(AR_AVY.CL_CODE, 'PRINCIPAL', DUE_AMT)), 0) PNP_DUE_AMT
# 	,nvl(max(decode(AR_AVY.CL_CODE, 'MAIN_INT', DUE_AMT)), 0) INT_DUE_AMT
# FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR
# LEFT JOIN (
# 	SELECT AR_AVY.*
# 		,CV.CL_CODE
# 	FROM AR_AVY
# 	JOIN CV ON AR_AVY.AVY_TP_ID = CV.CL_ID
# 		AND CV.CL_SCM_CODE = 'AVY_TP'
# 		AND AR_AVY.SRC_STM_ID = '92D4125CCD5B1BDF51F47FBCCDBBBF27'
# 		AND CV.CL_CODE IN (
# 			'PRINCIPAL'
# 			,'MAIN_INT'
# 			)
# 	) AR_AVY ON AC_AR.AC_AR_ID = AR_AVY.AR_ID
# LEFT JOIN (
# 	SELECT AVY_SHD.AR_AVY_ID
# 		,SUM(nvl(AVY_SHD.SHD_AMT, 0) - nvl(AVY_SHD.ACT_AMT, 0)) DUE_AMT
# 	FROM AR_AVY_SHD_ITM AVY_SHD
# 	WHERE AVY_SHD.EFF_DT <= #pDate#
# 		AND AVY_SHD.END_DT > #pDate#
# 		AND AVY_SHD.EXPC_END_DT <= #pDate#
# 		AND AVY_SHD.SHD_AMT > AVY_SHD.ACT_AMT
# 	GROUP BY AVY_SHD.AR_AVY_ID
# 	) AVY_SHD ON AR_AVY.AR_AVY_ID = AVY_SHD.AR_AVY_ID
# GROUP BY AC_AR.AC_AR_ID;
# SELECT AC_AR_ID, SUM(CLS_UTLZ_AMT_FCY) CLS_UTLZ_AMT_FCY
# FROM (
# SELECT AC_AR.AC_AR_ID , nvl(AR_X_AR.LINKED_AMT_FCY ,0) CLS_UTLZ_AMT_FCY
# 			FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR
# 			LEFT JOIN (SELECT AR_X_AR.SBJ_AR_ID, AR_X_AR.EFF_DT, AR_X_AR.END_DT, AR_X_AR.LINKED_AMT_FCY
# 			FROM AR_X_AR_RLTNP AR_X_AR JOIN CV ON AR_X_AR.SRC_STM_ID = CV.CL_ID
#                  AND CV.CL_SCM_CODE = 'SRC_STM'
#                  AND CL_CODE = 'FCC.CLTB_ACC_COLL_LINK_DTLS'
#                  WHERE AR_X_AR.EFF_DT <= #pdate# AND AR_X_AR.END_DT > #pdate#) AR_X_AR
#                  ON AC_AR.AC_AR_ID = AR_X_AR.SBJ_AR_ID
# where AC_AR.MUD = 'LN'
# AND AR_X_AR.EFF_DT <= AC_AR.LAST_EFF_DT AND AR_X_AR.END_DT > AC_AR.LAST_EFF_DT
# UNION
# SELECT AC_AR.AC_AR_ID , nvl(AR_X_RI.RI_AMT ,0) CLS_UTLZ_AMT_FCY
# 			FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR
# 			LEFT JOIN (SELECT AR_X_RI.AR_ID, AR_X_RI.EFF_DT, AR_X_RI.END_DT, AR_X_RI.RI_AMT
# 			FROM AR_X_RI_RLTNP AR_X_RI
#                  WHERE AR_X_RI.SRC_STM_ID = '0A173E8726B6D97003B5EE634C0CCA92'
#                  AND AR_X_RI.EFF_DT <= #pdate# AND AR_X_RI.END_DT > #pdate#) AR_X_RI
#                  ON AC_AR.AC_AR_ID = AR_X_RI.AR_ID
# where AC_AR.MUD = 'LN'
# AND AR_X_RI.EFF_DT <= AC_AR.LAST_EFF_DT AND AR_X_RI.END_DT > AC_AR.LAST_EFF_DT)
# GROUP BY AC_AR_ID;
# SELECT CHG.AC_AR_ID,
# PST_ENTR.PST_ENTR_AMT_LCY FEE_INCM_LCY
# FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG CHG
# LEFT JOIN PST_ENTR  ON PST_ENTR.REL_AR_ID = CHG.AC_AR_ID
# AND PST_DT = #pdate#
# LEFT JOIN AR_X_AU_RLTNP AR_X_AU ON CHG.AC_AR_ID = AR_X_AU.AR_ID
# AND AR_X_AU.SRC_STM_ID = '85425375A0630AA9C05A16D7D3420345'
# AND AR_X_AU.EFF_DT <= #pdate# AND AR_X_AU.END_DT > #pdate#
# LEFT JOIN AU ON AU.AU_ID = AR_X_AU.AU_ID
# WHERE CHG.PD_CODE IN ('C11M', 'C11S', 'M9P1', 'M9PM', 'M9PS', 'N9PS')
# AND AU.ACG_STC_ITM_ID IN (select function_hash02('GL' || '|' || 'FCC.GLTM_GLMASTER', FIELD1)
# from EXT_FCC_jrtb_parameters a where a.srv_id = 'GL023CB')
# AND ACG_TP_ID = '6BD323629A5B4A768A50D4F091BB2952' ;
# select
# 	chg.ac_ar_id,
# 	axr.EFF_RATE_PCT	INT_RATE
# from TWT_FNC_SVC_AR_ANL_FCT_FA_CHG chg
# left join ar_x_rate_tp_rltnp AXR on AXR.ar_x_rate_tp_rltnp_tp_id ='B1D1E14709EF08BBB38D361A980E4DE1'
#     AND AXR.RATE_TP_ID = '2EC90B394FDFF95D4EC063F17BE70B47'
#     AND AXR.RATE_CMPT = 'INTEREST_RATE'
# 	and AXR.ar_id = chg.AC_AR_ID AND AXR.EFF_DT <= LAST_EFF_DT AND AXR.END_DT > LAST_EFF_DT;
# SELECT
#  CHG.AC_AR_ID                                               AC_AR_ID
# ,decode(CHG.MUD, 'LN', XIP.IP_ID, CHG.CST_ID)           CST_ID
# ,CASE WHEN CHG.MUD IN ('OD', 'CARD') THEN '139900'
#     WHEN CHG.MUD = 'LN' THEN UDF.UDF_VAL
#     ELSE NULL END                                       LOAN_PPS_CODE
# ,CHG.PD_CODE                                            PD_CODE
# ,NVL(SALE.IP_ID, CHG.SALE_EMPE_ID)                      RLTNP_OFCR_ID
# ,IDY.UDF_VAL                                            IDY_CODE
# ,CHG.ACG_STC_ITM_ID                                     LDGR_ACG_ID
# ,NVL(XOU.IP_CODE, CHG.RPRG_OU_CODE)                     ADJ_OU_CODE
# ,CHG.CCY_CODE                                           ADJ_CCY_CODE
# ,CG.CL_ID                                               CG_SEG
# ,MSEG.CL_ID                                             MSEG
# ,EMPE.EMPE_NBR
# ,CHG.AR_UNQ_ID
# ,CASE WHEN CHG.MUD IN ('LN', 'OD') THEN 'FCC' ELSE 'SMV' END    PD_SRC_STM_CODE
# ,CHG.CARD_ID                                            PYMT_CARD_ID
# ,CHG.MUD
# ,CHG.RPRG_OU_CODE
# FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG CHG
# LEFT JOIN TMP_AR_X_CST XIP   ON XIP.AR_ID = AC_AR_ID AND XIP.EFF_DT <= LAST_EFF_DT AND XIP.END_DT > LAST_EFF_DT
# LEFT JOIN TMP_AR_X_SALE_PERSON SALE ON SALE.AR_ID = AC_AR_ID AND SALE.EFF_DT <= LAST_EFF_DT AND SALE.END_DT > LAST_EFF_DT
# LEFT JOIN TMP_AR_X_OU XOU ON XOU.AR_ID = AC_AR_ID AND XOU.EFF_DT <= LAST_EFF_DT AND XOU.END_DT > LAST_EFF_DT
# LEFT JOIN (SELECT UDF.*, CV.CL_CODE FROM AR_X_UDF_RLTNP UDF
#             INNER JOIN CV ON UDF.UDF_VAL_ID = CV.CL_ID AND CV.CL_CODE LIKE 'MUC DICH VAY.%'
#             INNER JOIN CV SRC ON SRC.CL_ID = UDF.SRC_STM_ID AND SRC.CL_CODE ='FCC.CLTB_ACCOUNT_APPS_MASTER'
#             ) UDF ON UDF.AR_ID = AC_AR_ID AND UDF.EFF_DT <= LAST_EFF_DT AND UDF.END_DT > LAST_EFF_DT
# LEFT JOIN (SELECT IDY.* FROM IP_X_UDF_RLTNP IDY
#             left join cv on cv.cl_id = idy.UDF_VAL_ID
#             WHERE IDY.UDF_ID = '13CDBEEEE9199559A9EF8794322E43E7'
#             AND CV.CL_CODE IS NOT NULL) IDY ON IDY.IP_ID = decode(CHG.MUD, 'LN', XIP.IP_ID, CHG.CST_ID) AND IDY.EFF_DT <= LAST_EFF_DT AND IDY.END_DT > LAST_EFF_DT
# LEFT JOIN TMP_CL_X_IP_INDUSTRY_TP CG ON decode(CHG.MUD, 'LN', XIP.IP_ID, CHG.CST_ID) = CG.IP_ID AND CG.EFF_DT <= LAST_EFF_DT AND CG.END_DT > LAST_EFF_DT
# LEFT JOIN TMP_CL_X_IP_MSEG MSEG ON decode(CHG.MUD, 'LN', XIP.IP_ID, CHG.CST_ID) = MSEG.IP_ID AND MSEG.EFF_DT <= LAST_EFF_DT AND MSEG.END_DT > LAST_EFF_DT
# LEFT JOIN EMPE ON SALE.IP_ID = EMPE.EMPE_ID;

# %%
import re
import pandas as pd
from pprint import pprint

def remove_comments(sql):
    # Loại bỏ các comment kiểu -- từ dấu -- cho đến khi gặp dấu xuống dòng \n
    sql = re.sub(r'--.*?\n', '', sql)
    # Loại bỏ các comment kiểu /* ... */
    sql = re.sub(r'/\*.*?\*/', '', sql, flags=re.DOTALL)
    return sql

def extract_jobs_and_sql(dsx_content):
    # Tìm tất cả các job với tên và vị trí bắt đầu
    job_matches = re.finditer(r'BEGIN DSJOB.*?Identifier "(.*?)"', dsx_content, re.DOTALL)
    jobs = [(match.start(), match.group(1)) for match in job_matches]

    # Tìm tất cả các đoạn CDATA chứa câu truy vấn SQL với vị trí của chúng
    sql_matches = re.finditer(r'<!\[CDATA\[(.*?)\]\]>', dsx_content, re.DOTALL | re.IGNORECASE)
    
    sql_queries = [(match.start(), match.group(1).strip()) for match in sql_matches]
    pprint(sql_queries)
    job_queries = []
    
    # Duyệt qua từng câu truy vấn và gán nó vào job tương ứng
    for sql_pos, query in sql_queries:
        # Loại bỏ comment trong câu truy vấn
        query = remove_comments(query)
        
        # Chỉ lấy những câu truy vấn bắt đầu bằng từ khóa SQL chính xác
        sql_keywords = ['SELECT', 'UPDATE', 'INSERT INTO', 'DELETE FROM', 'WITH']
        for keyword in sql_keywords:
            if query.upper().startswith(keyword):
                # Loại bỏ phần trước từ khóa và chỉ giữ lại câu truy vấn
                cleaned_query = re.sub(rf'^.*?\b{keyword}\b', keyword, query, flags=re.DOTALL | re.IGNORECASE)
                # Cắt bỏ bất kỳ phần nào sau dấu chấm phẩy đầu tiên
                cleaned_query = re.split(r';', cleaned_query)[0]
                
                # Thêm dấu chấm phẩy vào cuối câu nếu chưa có
                if not cleaned_query.endswith(';'):
                    cleaned_query += ';'

                # Xác định job chứa câu truy vấn này
                job_name = None
                for i in range(len(jobs) - 1):
                    if jobs[i][0] <= sql_pos < jobs[i + 1][0]:
                        job_name = jobs[i][1]
                        break
                if job_name is None and jobs:
                    job_name = jobs[-1][1]

                job_queries.append((job_name, cleaned_query))
                break

    return job_queries

# Đọc nội dung của file .dsx
with open('FNC_SVC_AR_FCT_FA.dsx', 'r', encoding='utf-8') as file:
    dsx_content = file.read()

# Gọi hàm để trích xuất tên job và các truy vấn SQL
job_queries = extract_jobs_and_sql(dsx_content)

# Hiển thị các job và các truy vấn SQL tương ứng
for job, query in job_queries:
    print(f"Job Name: {job}")
    #print(f"SQL Query: {query}\n")

# Chuyển đổi job_queries thành DataFrame
df = pd.DataFrame(job_queries, columns=["Job Name", "SQL Query"])

# Xuất DataFrame ra file Excel
df.to_excel("job_queries.xlsx", index=False)

print("Data has been exported to job_queries.xlsx")
# Out:
# [(7259, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (7351, '#PS_ORA_CONN_DMT.Username#'),
#  (7437, '#PS_ORA_CONN_DMT.Password#'),
#  (7534, '0'),
#  (7594, '11g'),
#  (7660, '0'),
#  (7709, '0'),
#  (7765, '0'),
#  (7845,
#   'SELECT\n'
#   '\tAC_AR_DIM.AC_AR_DIM_ID\t\t\t\t\tAC_AR_DIM_ID\n'
#   '\t,CST_DIM.CST_DIM_ID\t\t\t\t\t\tCST_DIM_ID\n'
#   '\t,LOAN_PPS_DIM.LOAN_PPS_DIM_ID\t\t\tLOAN_PPS_DIM_ID\n'
#   '\t,PD_DIM.PD_DIM_ID\t\t\t\t\t\tPD_DIM_ID\n'
#   '\t,RLTNP_OFCR.EMPE_DIM_ID\t\t\t\t\tRLTNP_OFCR_DIM_ID\n'
#   '\t,IDY_DIM.IDY_DIM_ID\t\t\t\t\t\tIDY_DIM_ID\n'
#   '\t,LDGR_ACG_DIM.LDGR_ACG_DIM_ID\t\t\tLDGR_ACG_DIM_ID\n'
#   '\t,TERM_DIM.GRP_DIM_ID\t\t\t\t\tTERM_DIM_ID\n'
#   '\t,ADJ_OU.OU_DIM_ID\t\t\t\t\t\tADJ_OU_DIM_ID\n'
#   '\t,ADJ_CCY.CCY_DIM_ID\t\t\t\t\t\tADJ_CCY_DIM_ID\n'
#   '\t,ADJ_LOB.LOB_DIM_ID\t\t\t\t\t\tADJ_LOB_DIM_ID\n'
#   '\t,CST_FNC_ST_DIM.FNC_ST_DIM_ID\t\t\tCST_FNC_ST_DIM_ID\n'
#   '\t,ADJ_FNC_ST_DIM.FNC_ST_DIM_ID\t\t\tADJ_FNC_ST_DIM_ID\n'
#   '\t,MIS_ADJ_FNC_ST_DIM.FNC_ST_DIM_ID\t\tMIS_ADJ_FNC_ST_DIM_ID\n'
#   '\t,FNL_FNC_ST_DIM.FNC_ST_DIM_ID\t\t\tFNL_FNC_ST_DIM_ID\n'
#   '\t,FNC_ST_TP_DIM.GRP_DIM_ID\t\t\t\tFNC_ST_TP_DIM_ID\n'
#   '\t,CG_SEGMENT_DIM.CG_SEG_DIM_ID\t\t\tCG_SEG_DIM_ID\n'
#   '\t,MSEG_DIM.MSEG_DIM_ID\t\t\t\t\tMSEG_DIM_ID\n'
#   '\t,T.CLS_BAL_FCY\n'
#   '\t,T.CLS_BAL_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'IW')\n"
#   '\t\t\t\tTHEN T.CLS_BAL_FCY\n'
#   '\t\tELSE nvl(lst.CLS_BAL_WTD_FCY, 0) + T.CLS_BAL_FCY\n'
#   '\tEND\t\t\t\t\t\t\t\t\t\t\t\t\tCLS_BAL_WTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'IW')\n"
#   '\t\t\t\tTHEN T.CLS_BAL_LCY\n'
#   '\t\tELSE nvl(lst.CLS_BAL_WTD_LCY, 0) + T.CLS_BAL_LCY\n'
#   '\tEND \t\t\t\t\t\t\t\t\t\t\t\tCLS_BAL_WTD_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN T.CLS_BAL_FCY\n'
#   '\t\tELSE nvl(lst.CLS_BAL_MTD_FCY, 0) + T.CLS_BAL_FCY\n'
#   '\tEND \t\t\t\t\t\t\t\t\t\t\t\tCLS_BAL_MTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN T.CLS_BAL_LCY\n'
#   '\t\tELSE nvl(lst.CLS_BAL_MTD_LCY, 0) + T.CLS_BAL_LCY\n'
#   '\tEND \t\t\t\t\t\t\t\t\t\t\t\tCLS_BAL_MTD_LCY\n'
#   '\t,T.LQD_AMT_FCY\n'
#   '\t,T.LQD_AMT_LCY\n'
#   '\t,T.DSBR_AMT_FCY\n'
#   '\t,T.DSBR_AMT_LCY\n'
#   '\t--ADD NEW\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN T.DSBR_AMT_LCY\n'
#   '\t\tELSE nvl(lst.DSBR_AMT_MTD_LCY, 0) + T.DSBR_AMT_LCY\n'
#   '\tEND \t\t\t\t\t\t\t\t\tDSBR_AMT_MTD_LCY\n'
#   '\t,T.PREPYMT_AMT_FCY\n'
#   '\t,T.PREPYMT_AMT_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN T.PREPYMT_AMT_FCY\n'
#   '\t\tELSE nvl(lst.PREPYMT_AMT_MTD_FCY, 0) + T.PREPYMT_AMT_FCY\n'
#   '\tEND \t\t\t\t\t\t\t\t\t\t\t\tPREPYMT_AMT_MTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN T.PREPYMT_AMT_LCY\n'
#   '\t\tELSE nvl(lst.PREPYMT_AMT_MTD_LCY, 0) + T.PREPYMT_AMT_LCY\n'
#   '\tEND     \t\t\t\t\t\t\t\t\t\t\tPREPYMT_AMT_MTD_LCY\n'
#   '\t,\t\t\t\t\t\t\t\t\t\t\t\t\tT.PY_OFF_BFR_DUE_DT_F\n'
#   '\t,\t\t\t\t\t\t\t\t\t\t\t\t\tT.INT_RATE\n'
#   '\t,#pdate#\t\t\t\t\t\t\t\t\t\t\tCDR_DT_DIM_ID\n'
#   "\t,decode(T.MUD, 'OD', 0, AC_AR_DIM.TERM_IN_MO)\t\tTERM_IN_MO\n"
#   '\t,SRO_DIM.SRO_DIM_ID\t\t\t\t\t\t\t\t\tSRO_DIM_ID\n'
#   '\t,T.PB_MISCODE_F\n'
#   '\t,T.PB_CST_F\n'
#   '\t,PYMTC_DIM.PYMTC_DIM_ID\t\t\t\t\t\t\t\tPYMTC_DIM_ID\n'
#   '\t,T.MUD\n'
#   '\t,LOB.LOB_DIM_ID\t\t\t\t\t\t\t\t\t\tLOB_DIM_ID\n'
#   '\t,OU.OU_DIM_ID\t\t\t\t\t\t\t\t\t\tOU_DIM_ID\n'
#   '\t,CIC_FNC_ST_DIM.FNC_ST_DIM_ID\t\t\t\t\t\tCIC_FNC_ST_DIM_ID\n'
#   '\t,CCY.CCY_DIM_ID\t\t\t\t\t\t\t\t\t\tCCY_DIM_ID\n'
#   '\t,FNC_SVC_MINI.FNC_SVC_AR_MINI_DIM_ID\t\t\t\tFNC_SVC_AR_MINI_DIM_ID\n'
#   '\t,OVRL_CST.FNC_ST_DIM_ID\t\t\t\t\t\t\t\tOVRL_CST_FNC_ST_DIM_ID\n'
#   '\t,OVRL_MIS_ADJ.FNC_ST_DIM_ID\t\t\t\t\t\t\tOVRL_MIS_ADJ_FNC_ST_DIM_ID\n'
#   '\t,OVRL_FNL.FNC_ST_DIM_ID\t\t\t\t\t\t\t\tOVRL_FNL_FNC_ST_DIM_ID\n'
#   '\t,T.ORIG_CLS_BAL_FCY\n'
#   '\t,T.ORIG_CLS_BAL_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN T.ORIG_CLS_BAL_FCY\n'
#   '\t\tELSE nvl(lst.ORIG_CLS_BAL_MTD_FCY, 0) + T.ORIG_CLS_BAL_FCY\n'
#   '\tEND \t\t\t\t\t\t\t\t\t\t\t\tORIG_CLS_BAL_MTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN T.ORIG_CLS_BAL_LCY\n'
#   '\t\tELSE nvl(lst.ORIG_CLS_BAL_MTD_LCY, 0) + T.ORIG_CLS_BAL_LCY\n'
#   '\tEND \t\t\t\t\t\t\t\t\t\t\t\tORIG_CLS_BAL_MTD_LCY\n'
#   '\t,PD_DIM.PD_CODE||FNC_SVC_MINI.DTL_PD_CODE\t\t\tCMB_PD_CODE\n'
#   '\t--ADD\n'
#   '\t,ORIG_PD.PD_DIM_ID\t\t\t\t\t\t\t\t\tORIG_PD_DIM_ID\n'
#   '\t,MID1_OU.OU_DIM_ID\t\t\t\t\t\t\t\t\tMIS1_OU_DIM_ID\n'
#   '\t,NVL(PD_DTL.PD_DTL_GRP_DIM_ID, PD_DTL1.PD_DTL_GRP_DIM_ID)\t'
#   'PD_DTL_GRP_DIM_ID\n'
#   '-- Add new luc.luu\n'
#   '                ,T.FEE_INCM_LCY\n'
#   '                ,T.TOT_LMT_AMT\n'
#   "               -- , CASE WHEN AC_AR_DIM.AC_AR_TP = 'OD' THEN "
#   "TO_DATE(#pdate#,'YYYYMMDD') - AC_AR_DIM.AR_END_DT \n"
#   "               -- \tELSE TO_DATE(#pdate#,'YYYYMMDD') - "
#   "TO_DATE(T.MAX_DAY_PAST_DUE,'YYYYMMDD') END NOD_PAST_DUE\n"
#   '                ,T.NOD_PAST_DUE\n'
#   '                ,T.PNP_ARS TOT_PAST_DUE_PNP\n'
#   '                ,T.INT_ARS TOT_PAST_DUE_INT\n'
#   '                ,T.CLS_UTLZ_AMT_FCY\n'
#   '                ,T.PNP_DUE_AMT\n'
#   '                ,T.INT_DUE_AMT\n'
#   '                ,T.DLQ_CNT\n'
#   ',T.TOT_DSBR_AMT_FCY\n'
#   ',AC_AR_MINI.AC_AR_MINI_DIM_ID\n'
#   ',T.TOT_AVL_LMT_AMT\n'
#   ',T.INTERIM_INT\n'
#   ',ORIG_OU.OU_DIM_ID ORIG_OU_DIM_ID\n'
#   ',CST_SEG_MINI_DIM.CST_SEG_MINI_DIM_ID\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA T\n'
#   'INNER JOIN AC_AR_DIM \t\t\t\t\tON AC_AR_DIM.AC_AR_ID = T.AC_AR_ID AND '
#   'AC_AR_DIM.EFF_DT <= #pdate# AND AC_AR_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN TWT_FCA_ANL_FCT_FA_LST_DY LST ON AC_AR_DIM.AC_AR_ID = '
#   'LST.AC_AR_ID AND LST.CDR_DT_DIM_ID = to_number(to_char(to_date(#pdate#, '
#   "'yyyymmdd')-1, 'yyyymmdd'))\n"
#   'LEFT JOIN FNC_SVC_AR_MINI_DIM FNC_SVC_MINI\tON FNC_SVC_MINI.FNC_SVC_AR_ID = '
#   'T.AC_AR_ID AND FNC_SVC_MINI.EFF_DT <= #pdate# AND FNC_SVC_MINI.END_DT > '
#   '#pdate#\n'
#   '--add 20220311\n'
#   'LEFT JOIN TWT_FNC_SVC_AR_FCT_FA_CST_PD PD_CST ON T.AC_AR_ID = '
#   'PD_CST.AC_AR_ID --AND T.PD_CODE = PD_CST.PD_CODE \n'
#   'LEFT JOIN TWT_PUB_AC_AR_INFO TB_IF ON TB_IF.AR_ID = T.AC_AR_ID\n'
#   'LEFT JOIN AC_AR_MINI_DIM AC_AR_MINI ON AC_AR_MINI.EFF_DT<=#pdate# AND '
#   'AC_AR_MINI.END_DT>#pdate#\n'
#   "\tAND NVL(PD_CST.GL_FNC_ST_CODE, 'NULL') = AC_AR_MINI.AR_FNC_ST\n"
#   "\tAND NVL(PD_CST.CST_PD_FNC_ST_CODE, 'NULL') = "
#   'AC_AR_MINI.CST_PD_FNC_ST_CODE\n'
#   "\tAND nvl(TB_IF.CST_INCM_F,'N') = AC_AR_MINI.CST_INCM_F\n"
#   '--END ADD\n'
#   'LEFT JOIN CST_DIM \t\t\t\t\t\tON CST_DIM.CST_ID = T.CST_ID AND '
#   'CST_DIM.EFF_DT <= #pdate# AND CST_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN LOAN_PPS_DIM \t\t\t\t\tON LOAN_PPS_DIM.PPS_CODE = T.LOAN_PPS_CODE '
#   'AND LOAN_PPS_DIM.EFF_DT <= #pdate# AND LOAN_PPS_DIM.END_DT > #pdate# AND '
#   "LOAN_PPS_DIM.PPS_TP = 'MUC DICH VAY'\n"
#   'LEFT JOIN PD_DIM \t\t\t\t\t\tON PD_DIM.PD_CODE = T.PD_CODE AND '
#   'PD_DIM.EFF_DT <= #pdate# AND PD_DIM.END_DT > #pdate#\n'
#   "\t\t\t\t\t\t\t\t\t\tAND CASE WHEN T.MUD IN ('LN', 'OD') THEN 'FCC' ELSE "
#   "'SMV' END = SUBSTR(PD_DIM.SRC_STM_CODE, 1, INSTR(PD_DIM.SRC_STM_CODE, "
#   "'.')-1)\n"
#   'LEFT JOIN PD_DIM ORIG_PD \t\t\t\tON ORIG_PD.PD_CODE = T.ORIG_PD_CODE AND '
#   'ORIG_PD.EFF_DT <= #pdate# AND ORIG_PD.END_DT > #pdate#\n'
#   "\t\t\t\t\t\t\t\t\t\tAND CASE WHEN T.MUD IN ('LN', 'OD') THEN 'FCC' ELSE "
#   "'SMV' END = SUBSTR(ORIG_PD.SRC_STM_CODE, 1, INSTR(ORIG_PD.SRC_STM_CODE, "
#   "'.')-1)\n"
#   'LEFT JOIN EMPE_DIM RLTNP_OFCR \t\t\tON RLTNP_OFCR.EMPE_ID = T.RLTNP_OFCR_ID '
#   'AND RLTNP_OFCR.EFF_DT <= #pdate# AND RLTNP_OFCR.END_DT > #pdate#\n'
#   'LEFT JOIN IDY_DIM \t\t\t\t\t\tON IDY_DIM.IDY_SHRT_CODE = T.IDY_CODE AND '
#   'IDY_DIM.EFF_DT <= #pdate# AND IDY_DIM.END_DT > #pdate# AND '
#   "SUBSTR(IDY_DIM.IDY_CODE, 1, INSTR(IDY_DIM.IDY_CODE, '.')-1) = "
#   "'NGANH_NGHE_KINH_TE_SBV'\n"
#   'LEFT JOIN LDGR_ACG_DIM \t\t\t\t\tON LDGR_ACG_DIM.LDGR_ACG_ID = '
#   'T.LDGR_ACG_ID AND LDGR_ACG_DIM.EFF_DT <= #pdate# AND LDGR_ACG_DIM.END_DT > '
#   '#pdate#\n'
#   'LEFT JOIN GRP_DIM TERM_DIM\t\t\t\tON TERM_DIM.GRP_CODE = decode(T.MUD, '
#   "'OD', 'S', CASE WHEN AC_AR_DIM.TERM_IN_MO <= 12 THEN 'S' WHEN "
#   "AC_AR_DIM.TERM_IN_MO <= 60 THEN 'M' ELSE 'L' END)\n"
#   "\t\t\t\t\t\t\t\t\t\tAND TERM_DIM.PRN_GRP_CODE = 'TERM_SEG_TP' AND "
#   'TERM_DIM.EFF_DT <= #pdate# AND TERM_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN OU_DIM ADJ_OU \t\t\t\tON ADJ_OU.CODE = T.ADJ_OU_CODE AND '
#   'ADJ_OU.EFF_DT <= #pdate# AND ADJ_OU.END_DT > #pdate#\n'
#   'LEFT JOIN OU_DIM OU\t\t\t\t\t\tON OU.CODE = T.OU_CODE AND OU.EFF_DT <= '
#   '#pdate# AND OU.END_DT > #pdate#\n'
#   'LEFT JOIN OU_DIM MID1_OU\t\t\t\tON MID1_OU.CODE = T.MIS1_OU_CODE AND '
#   'MID1_OU.EFF_DT <= #pdate# AND MID1_OU.END_DT > #pdate#\n'
#   'LEFT JOIN CCY_DIM ADJ_CCY \t\t\t\tON ADJ_CCY.ALPB_CCY_CODE = T.ADJ_CCY_CODE '
#   'AND ADJ_CCY.EFF_DT <= #pdate# AND ADJ_CCY.END_DT > #pdate#\n'
#   'LEFT JOIN CCY_DIM CCY \t\t\t\t\tON CCY.ALPB_CCY_CODE = T.CCY_CODE AND '
#   'CCY.EFF_DT <= #pdate# AND CCY.END_DT > #pdate#\n'
#   'LEFT JOIN LOB_DIM ADJ_LOB\t\t\t\tON ADJ_LOB.LOB_CODE = T.ADJ_LOB_CODE\n'
#   'LEFT JOIN LOB_DIM LOB\t\t\t\t\tON LOB.LOB_CODE = T.LOB_CODE\n'
#   '--add 20200605\n'
#   'LEFT JOIN PD_DTL_GRP_DIM PD_DTL\t\t\tON PD_DTL.LINE = ADJ_LOB.LOB_CODE AND '
#   'PD_DTL.MAP_SPCT = PD_DIM.PD_CODE||FNC_SVC_MINI.DTL_PD_CODE\n'
#   '\t\t\t\t\t\t\t\t\t\tAND PD_DTL.EFF_DT <= #pdate# AND PD_DTL.END_DT > '
#   '#pdate#\n'
#   'LEFT JOIN PD_DTL_GRP_DIM PD_DTL1\t\t\tON PD_DTL1.LINE = ADJ_LOB.LOB_CODE '
#   'AND PD_DTL1.MAP_SPCT = ORIG_PD.PD_CODE\n'
#   '\t\t\t\t\t\t\t\t\t\tAND PD_DTL1.EFF_DT <= #pdate# AND PD_DTL1.END_DT > '
#   '#pdate#\n'
#   '--END ADD\n'
#   'LEFT JOIN FNC_ST_DIM ADJ_FNC_ST_DIM \tON ADJ_FNC_ST_DIM.FNC_ST_CODE = '
#   'T.ADJ_FNC_ST_CODE AND ADJ_FNC_ST_DIM.EFF_DT <= #pdate# AND '
#   'ADJ_FNC_ST_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN FNC_ST_DIM CST_FNC_ST_DIM \tON CST_FNC_ST_DIM.FNC_ST_CODE = '
#   'T.CST_FNC_ST_CODE AND CST_FNC_ST_DIM.EFF_DT <= #pdate# AND '
#   'CST_FNC_ST_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN FNC_ST_DIM MIS_ADJ_FNC_ST_DIM ON MIS_ADJ_FNC_ST_DIM.FNC_ST_CODE = '
#   'T.MIS_ADJ_FNC_ST_CODE AND MIS_ADJ_FNC_ST_DIM.EFF_DT <= #pdate# AND '
#   'MIS_ADJ_FNC_ST_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN FNC_ST_DIM FNL_FNC_ST_DIM \tON FNL_FNC_ST_DIM.FNC_ST_CODE = '
#   'T.FNL_FNC_ST_CODE AND FNL_FNC_ST_DIM.EFF_DT <= #pdate# AND '
#   'FNL_FNC_ST_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN FNC_ST_DIM OVRL_CST \t\t\tON OVRL_CST.FNC_ST_CODE = '
#   'T.OVRL_CST_FNC_ST_CODE AND OVRL_CST.EFF_DT <= #pdate# AND OVRL_CST.END_DT > '
#   '#pdate#\n'
#   'LEFT JOIN FNC_ST_DIM OVRL_MIS_ADJ \t\tON OVRL_MIS_ADJ.FNC_ST_CODE = '
#   'T.OVRL_MIS_ADJ_FNC_ST_CODE AND OVRL_MIS_ADJ.EFF_DT <= #pdate# AND '
#   'OVRL_MIS_ADJ.END_DT > #pdate#\n'
#   'LEFT JOIN FNC_ST_DIM OVRL_FNL \t\t\tON OVRL_FNL.FNC_ST_CODE = '
#   'T.OVRL_FNL_FNC_ST_CODE AND OVRL_FNL.EFF_DT <= #pdate# AND OVRL_FNL.END_DT > '
#   '#pdate#\n'
#   'LEFT JOIN FNC_ST_DIM CIC_FNC_ST_DIM \tON CIC_FNC_ST_DIM.FNC_ST_CODE = '
#   'T.CIC_FNC_ST_CODE AND CIC_FNC_ST_DIM.EFF_DT <= #pdate# AND '
#   'CIC_FNC_ST_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN GRP_DIM FNC_ST_TP_DIM \t\tON FNC_ST_TP_DIM.GRP_CODE = '
#   'T.FNC_ST_TP_CODE AND FNC_ST_TP_DIM.EFF_DT <= #pdate# AND '
#   'FNC_ST_TP_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN CG_SEG_DIM CG_SEGMENT_DIM \tON CG_SEGMENT_DIM.CG_SEG_ID = '
#   'T.CG_SEG AND CG_SEGMENT_DIM.EFF_DT <= #pdate# AND CG_SEGMENT_DIM.END_DT > '
#   '#pdate#\n'
#   'LEFT JOIN MSEG_DIM \t\t\t\t\t\tON MSEG_DIM.MSEG_ID = T.MSEG AND '
#   'MSEG_DIM.EFF_DT <= #pdate# AND MSEG_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN SRO_DIM \t\t\t\t\t\tON SRO_DIM.SRO_CODE = T.SRO_CODE AND '
#   'SRO_DIM.EFF_DT <= #pdate# AND SRO_DIM.END_DT > #pdate#\n'
#   'LEFT JOIN PYMTC_DIM \t\t\t\t\tON PYMTC_DIM.PYMTC_ID = T.PYMT_CARD_ID AND '
#   'PYMTC_DIM.EFF_DT <= #pdate# AND PYMTC_DIM.END_DT > #pdate#\n'
#   '--add 20220311\n'
#   'LEFT JOIN OU_DIM ORIG_OU ON ORIG_OU.CODE = T.RPRG_OU_CODE AND '
#   'ORIG_OU.EFF_DT <= #pdate# AND ORIG_OU.END_DT > #pdate#\n'
#   'LEFT JOIN TWT_PUB_CST_INFO ON TWT_PUB_CST_INFO.IP_ID = T.CST_ID\n'
#   'LEFT JOIN CST_SEG_MINI_DIM ON\n'
#   '\tTWT_PUB_CST_INFO.LCS = CST_SEG_MINI_DIM.LCS\n'
#   '\tAND TWT_PUB_CST_INFO.FN_ST = CST_SEG_MINI_DIM.FNC_ST_CODE\n'
#   '\tAND TWT_PUB_CST_INFO.CLT_F = CST_SEG_MINI_DIM.CLT_F\n'
#   '\t\t\t\t\t\t\t\t\t\t\n'
#   'UNION ALL\n'
#   'SELECT \n'
#   '\tLST.AC_AR_DIM_ID\n'
#   '\t,LST.CST_DIM_ID\n'
#   '\t,LST.LOAN_PPS_DIM_ID\n'
#   '\t,LST.PD_DIM_ID\n'
#   '\t,LST.RLTNP_OFCR_DIM_ID\n'
#   '\t,LST.IDY_DIM_ID\n'
#   '\t,LST.LDGR_ACG_DIM_ID\n'
#   '\t,LST.TERM_DIM_ID\n'
#   '\t,LST.ADJ_OU_DIM_ID\n'
#   '\t,LST.ADJ_CCY_DIM_ID\n'
#   '\t,LST.ADJ_LOB_DIM_ID\n'
#   '\t,LST.CST_FNC_ST_DIM_ID\n'
#   '\t,LST.ADJ_FNC_ST_DIM_ID\n'
#   '\t,LST.MIS_ADJ_FNC_ST_DIM_ID\n'
#   '\t,LST.FNL_FNC_ST_DIM_ID\n'
#   '\t,LST.FNC_ST_TP_DIM_ID\n'
#   '\t,LST.CG_SEG_DIM_ID\n'
#   '\t,LST.MSEG_DIM_ID\n'
#   '\t,0 CLS_BAL_FCY\n'
#   '\t,0 CLS_BAL_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'IW')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.CLS_BAL_WTD_FCY END CLS_BAL_WTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'IW')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.CLS_BAL_WTD_LCY END CLS_BAL_WTD_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.CLS_BAL_MTD_FCY END CLS_BAL_MTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.CLS_BAL_MTD_LCY END CLS_BAL_MTD_LCY\n'
#   '\t,0 LQD_AMT_FCY\n'
#   '\t,0 LQD_AMT_LCY\n'
#   '\t,0 DSBR_AMT_FCY\n'
#   '\t,0 DSBR_AMT_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.DSBR_AMT_MTD_LCY END DSBR_AMT_MTD_LCY\n'
#   '\t,0 PREPYMT_AMT_FCY\n'
#   '\t,0 PREPYMT_AMT_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.PREPYMT_AMT_MTD_FCY END PREPYMT_AMT_MTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.PREPYMT_AMT_MTD_LCY END PREPYMT_AMT_MTD_LCY\n'
#   '\t,LST.PY_OFF_BFR_DUE_DT_F\n'
#   '\t,LST.INT_RATE\n'
#   '\t,LST.CDR_DT_DIM_ID\n'
#   '\t,LST.TERM_IN_MO\n'
#   '\t,LST.SRO_DIM_ID\n'
#   '\t,LST.PB_MISCODE_F\n'
#   '\t,LST.PB_CST_F\n'
#   '\t,LST.PYMTC_DIM_ID\n'
#   '\t,LST.MUD\n'
#   '\t,LST.LOB_DIM_ID\n'
#   '\t,LST.OU_DIM_ID\n'
#   '\t,LST.CIC_FNC_ST_DIM_ID\n'
#   '\t,LST.CCY_DIM_ID\n'
#   '\t,LST.FNC_SVC_AR_MINI_DIM_ID\n'
#   '\t,LST.OVRL_CST_FNC_ST_DIM_ID\n'
#   '\t,LST.OVRL_MIS_ADJ_FNC_ST_DIM_ID\n'
#   '\t,LST.OVRL_FNL_FNC_ST_DIM_ID\n'
#   '\t,0 ORIG_CLS_BAL_FCY\n'
#   '\t,0 ORIG_CLS_BAL_LCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.ORIG_CLS_BAL_MTD_FCY END ORIG_CLS_BAL_MTD_FCY\n'
#   "\t,CASE WHEN TO_DATE(#pdate#, 'YYYYMMDD') = TRUNC(TO_DATE(#pdate#, "
#   "'YYYYMMDD'), 'MONTH')\n"
#   '\t\t\t\tTHEN 0\n'
#   '\t\tELSE LST.ORIG_CLS_BAL_MTD_LCY END ORIG_CLS_BAL_MTD_LCY\n'
#   '\t,LST.CMB_PD_CODE\n'
#   '\t,LST.ORIG_PD_DIM_ID\n'
#   '\t,LST.MIS1_OU_DIM_ID\n'
#   '\t,LST.PD_DTL_GRP_DIM_ID\n'
#   '\t,0 FEE_INCM_LCY\n'
#   '\t,0 TOT_LMT_AMT\n'
#   '\t,0 NOD_PAST_DUE\n'
#   '\t,0 TOT_PAST_DUE_PNP\n'
#   '\t,0 TOT_PAST_DUE_INT\n'
#   '\t,0 CLS_UTLZ_AMT_FCY\n'
#   '\t,0 PNP_DUE_AMT\n'
#   '\t,0 INT_DUE_AMT\n'
#   '\t,0 DLQ_CNT\n'
#   '\t,0 TOT_DSBR_AMT_FCY\n'
#   '\t,LST.AC_AR_MINI_DIM_ID\n'
#   '\t,0 TOT_AVL_LMT_AMT\n'
#   '\t,0 INTERIM_INT\n'
#   '\t,LST.ORIG_OU_DIM_ID\n'
#   '\t,LST.CST_SEG_MINI_DIM_ID\n'
#   'FROM FNC_SVC_AR_ANL_FCT_FA LST\n'
#   'JOIN AC_AR_DIM AC ON AC.AC_AR_DIM_ID = LST.AC_AR_DIM_ID\n'
#   "WHERE LST.CDR_DT_DIM_ID = to_number(to_char(to_date(#pdate#, 'yyyymmdd') - "
#   "1, 'yyyymmdd'))\n"
#   '\tAND NOT EXISTS (\n'
#   '\t\tSELECT 1\n'
#   '\t\tFROM TWT_FNC_SVC_AR_ANL_FCT_FA T\n'
#   '\t\tWHERE T.AC_AR_ID = AC.AC_AR_ID\n'
#   '\t\t);'),
#  (21212, '0'),
#  (21423, '0'),
#  (21501, '0'),
#  (21555, '2000'),
#  (21607, '0'),
#  (21677, '2000'),
#  (21734, '1'),
#  (21797, '0'),
#  (21873, '0'),
#  (21928, '0'),
#  (21990, '0'),
#  (22066, '1'),
#  (22156, '0'),
#  (22237, '0'),
#  (22316, '0'),
#  (78468, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (78560, '#PS_ORA_CONN_DMT.Username#'),
#  (78646, '#PS_ORA_CONN_DMT.Password#'),
#  (78743, '0'),
#  (78803, '11g'),
#  (78883, '0'),
#  (78946, '1'),
#  (79011, 'FNC_SVC_AR_ANL_FCT_FA'),
#  (79067, '0'),
#  (79134, '0'),
#  (79227, '0'),
#  (79294, '0'),
#  (79348, '2000'),
#  (79423, '2000'),
#  (79484, '0'),
#  (79554, '0'),
#  (79627, '1'),
#  (79695, '1'),
#  (79789, '0'),
#  (79868, '1'),
#  (79919, 'Delete from FNC_SVC_AR_ANL_FCT_FA where CDR_DT_DIM_ID = #pdate#'),
#  (80029, '0'),
#  (80091, '1'),
#  (80154, ''),
#  (80200, '0'),
#  (80261, '1'),
#  (80328, ''),
#  (80379, '0'),
#  (80445, '1'),
#  (80516, ''),
#  (80566, '0'),
#  (80631, '1'),
#  (80741, '0'),
#  (80820, '0'),
#  (80882, '0'),
#  (89970, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (90062, '#PS_ORA_CONN_SOR.Username#'),
#  (90148, '#PS_ORA_CONN_SOR.Password#'),
#  (90245, '0'),
#  (90305, '11g'),
#  (90371, '0'),
#  (90420, '0'),
#  (90476, '0'),
#  (90556,
#   'SELECT\n'
#   '\tAC_AR.AC_AR_ID\n'
#   '\t,PD_AR.PD_ID\n'
#   '\t,COALESCE(LN.LAST_EFF_DT, OD.LAST_EFF_DT, CARD.LAST_EFF_DT)\t\t\t\t\t\t\t'
#   'LAST_EFF_DT\n'
#   '\t,COALESCE(LN.ADJ_BAL, OD.ADJ_BAL, CARD.ADJ_BAL)\t\t\t\t\t\t\t\t\t\t'
#   'ADJ_BAL\n'
#   '\t,AR.UNQ_ID_IN_SRC_STM\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAR_UNQ_ID\n'
#   '\t,CASE WHEN\n'
#   "\t\tCASE WHEN LN.AR_ID IS NOT NULL THEN 'LN'\n"
#   "\t\t\tWHEN OD.AR_ID IS NOT NULL THEN 'OD'\n"
#   "\t\t\tWHEN CARD.AR_ID IS NOT NULL THEN 'CARD'\n"
#   "\t\tEND IN ('OD', 'CARD') THEN PD_AR.PRM_CST_ID\n"
#   '\tELSE NULL END\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCST_ID\n'
#   "\t,CASE WHEN LN.AR_ID IS NOT NULL THEN 'LN'\n"
#   "\t\tWHEN OD.AR_ID IS NOT NULL THEN 'OD'\n"
#   "\t\tWHEN CARD.AR_ID IS NOT NULL THEN 'CARD'\n"
#   '\tEND\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMUD\n'
#   '\t,PD.UNQ_ID_IN_SRC_STM\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPD_CODE\n'
#   '\t,CCY.CCY_CODE\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCCY_CODE\n'
#   '\t,CARD.CARD_ID\n'
#   '\t,CARD_AR.SALE_EMPE_ID\n'
#   '\t,COALESCE(LN.ACG_STC_ITM_ID, OD.ACG_STC_ITM_ID, '
#   'AU.ACG_STC_ITM_ID)\t\t\t\t\tACG_STC_ITM_ID\n'
#   "\t,NVL(MAP.MA_NHOM_NO, 'NORM') \t\t\t\t\t\t\t\t\t\t\t\t\t\t"
#   'CARD_AR_FNC_ST_TP_CODE\n'
#   '\t,RPRG_OU.UNQ_ID_IN_SRC_STM\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tRPRG_OU_CODE\n'
#   '\t,LN.LN_FNC_ST_CODE\n'
#   'FROM AC_AR\n'
#   'LEFT JOIN TWT_CUST_LOAN_FA LN ON AC_AR.AC_AR_ID = LN.AR_ID\n'
#   'LEFT JOIN TWT_CST_OD_OPEN OD\tON AC_AR.AC_AR_ID = OD.AR_ID\n'
#   'LEFT JOIN TWT_CARD_OPEN CARD\tON AC_AR.AC_AR_ID = CARD.AR_ID\n'
#   'LEFT JOIN AR           \t\t\tON AC_AR.AC_AR_ID = AR.AR_ID\n'
#   'LEFT JOIN IP RPRG_OU\t\t\tON RPRG_OU.IP_ID = AR.RPRG_OU_ID\n'
#   'LEFT JOIN PD_AR         \t\tON AC_AR.AC_AR_ID = PD_AR.PD_AR_ID\n'
#   'LEFT JOIN PD \t\t\t\t\tON PD.PD_ID = PD_AR.PD_ID\n'
#   'LEFT JOIN CCY \t\t\t\t\tON CCY.CCY_ID = AR.DNMN_CCY_ID\n'
#   '--ADD NEW \n'
#   'LEFT JOIN AR CARD_AR\t\t\tON CARD_AR.AR_ID = CARD.CARD_ID\n'
#   'LEFT JOIN TMP_AR_X_AU AU\t\tON AU.AR_ID = CARD.AR_ID AND AU.AR_X_AU_TP_CODE '
#   "= 'AR_X_DR_AU'\n"
#   'LEFT JOIN CC_AR_SMY SMY\t\t\tON CARD.AR_ID = SMY.CC_AR_ID --CR_FCY_AR_ID = '
#   'TAI KHOAN THE\n'
#   '\tAND smy.MSR_PRD_ID = #pDate#\n'
#   'LEFT JOIN EXT_XLS_MAP_NHOMNO_THE_TDY MAP ON SMY.NOD_PAST_DUE < '
#   'NVL(MAP.HIGH_VAL, SMY.NOD_PAST_DUE + 1)\n'
#   '\tAND SMY.NOD_PAST_DUE >= NVL(MAP.LOW_VAL, SMY.NOD_PAST_DUE)\n'
#   '\tAND SMY.NOD_PAST_DUE >= NVL(MAP.LOW_VAL, SMY.NOD_PAST_DUE)\n'
#   'WHERE AC_AR.SRC_STM_ID IN '
#   "('3FBF9A0B41B2BE2CA30C68E2B64D00A7','85425375A0630AA9C05A16D7D3420345','D461039F96DF94CBDFD7BC02909C9521')\n"
#   'AND COALESCE(LN.AR_ID,OD.AR_ID,CARD.AR_ID) IS NOT NULL'),
#  (92693, '0'),
#  (92904, '0'),
#  (92982, '0'),
#  (93036, '2000'),
#  (93088, '0'),
#  (93158, '2000'),
#  (93215, '1'),
#  (93278, '0'),
#  (93354, '0'),
#  (93409, '0'),
#  (93471, '0'),
#  (93547, '1'),
#  (93637, '0'),
#  (93718, '0'),
#  (93797, '0'),
#  (110774, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (110866, '#PS_ORA_CONN_SOR.Username#'),
#  (110952, '#PS_ORA_CONN_SOR.Password#'),
#  (111049, '0'),
#  (111109, '11g'),
#  (111189, '0'),
#  (111252, '1'),
#  (111317, 'TWT_FNC_SVC_AR_ANL_FCT_FA_CHG'),
#  (111381, '0'),
#  (111448, '0'),
#  (111527, '3'),
#  (111579, '1'),
#  (111617, '1'),
#  (111702, '1'),
#  (111788, '0'),
#  (111842, '2000'),
#  (111917, '2000'),
#  (111978, '0'),
#  (112048, '0'),
#  (112121, '1'),
#  (112189, '1'),
#  (112283, '0'),
#  (112363, '0'),
#  (112444, '0'),
#  (112523, '0'),
#  (112585, '0'),
#  (121540, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (121632, '#PS_ORA_CONN_DMT.Username#'),
#  (121718, '#PS_ORA_CONN_DMT.Password#'),
#  (121815, '0'),
#  (121875, '11g'),
#  (121941, '0'),
#  (121990, '0'),
#  (122046, '0'),
#  (122126,
#   'SELECT A.AC_AR_ID\n'
#   '\t,A.CST_ID\n'
#   '\t,A.PD_CODE\n'
#   '\t,A.PD_SRC_STM_CODE\n'
#   '\t,A.ADJ_FNC_ST_CODE GL_FNC_ST_CODE\n'
#   '\t,MAX(ADJ_FNC_ST_CODE) OVER(PARTITION BY A.CST_ID, A.PD_CODE, '
#   'A.PD_SRC_STM_CODE) CST_PD_FNC_ST\n'
#   'FROM TWT_FNC_SVC_AR_FCT_FA A'),
#  (122389, '0'),
#  (122600, '0'),
#  (122678, '0'),
#  (122732, '2000'),
#  (122784, '0'),
#  (122854, '2000'),
#  (122911, '1'),
#  (122974, '0'),
#  (123050, '0'),
#  (123105, '0'),
#  (123167, '0'),
#  (123243, '1'),
#  (123333, '0'),
#  (123414, '0'),
#  (123493, '0'),
#  (132489, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (132581, '#PS_ORA_CONN_DMT.Username#'),
#  (132667, '#PS_ORA_CONN_DMT.Password#'),
#  (132764, '0'),
#  (132824, '11g'),
#  (132904, '0'),
#  (132967, '1'),
#  (133032, 'TWT_FNC_SVC_AR_FCT_FA_CST_PD'),
#  (133095, '0'),
#  (133162, '0'),
#  (133241, '2'),
#  (133291, '1'),
#  (133329, '1'),
#  (133417, '1'),
#  (133455, '0'),
#  (133536, '1'),
#  (133622, '0'),
#  (133676, '2000'),
#  (133751, '2000'),
#  (133812, '0'),
#  (133882, '0'),
#  (133955, '1'),
#  (134023, '1'),
#  (134117, '0'),
#  (134197, '0'),
#  (134278, '0'),
#  (134357, '0'),
#  (134419, '0'),
#  (143853, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (143945, '#PS_ORA_CONN_DMT.Username#'),
#  (144031, '#PS_ORA_CONN_DMT.Password#'),
#  (144128, '0'),
#  (144188, '11g'),
#  (144254, '0'),
#  (144303, '0'),
#  (144359, '0'),
#  (144439,
#   'SELECT\n'
#   '\tAC_AR_DIM.AC_AR_ID\n'
#   '\t,CLS_BAL_WTD_FCY\n'
#   '\t,CLS_BAL_WTD_LCY\n'
#   '\t,CLS_BAL_MTD_FCY\n'
#   '\t,CLS_BAL_MTD_LCY\n'
#   '\t,PREPYMT_AMT_MTD_FCY\n'
#   '\t,PREPYMT_AMT_MTD_LCY\n'
#   '\t,CDR_DT_DIM_ID\n'
#   '\t,DSBR_AMT_MTD_LCY\n'
#   '\t,ORIG_CLS_BAL_MTD_FCY\n'
#   '\t,ORIG_CLS_BAL_MTD_LCY\n'
#   'FROM FNC_SVC_AR_ANL_FCT_FA FCT\n'
#   'LEFT JOIN AC_AR_DIM ON AC_AR_DIM.AC_AR_DIM_ID = FCT.AC_AR_DIM_ID\n'
#   "WHERE FCT.CDR_DT_DIM_ID = to_number(to_char(to_date(#pDate#, 'yyyymmdd')-1, "
#   "'yyyymmdd'))\n"
#   'AND FCT.SRO_DIM_ID = 7;'),
#  (144915, '0'),
#  (144992, 'FNC_SVC_AR_ANL_FCT_FA'),
#  (145054, 'AC_AR_DIM'),
#  (145176, 'ORIG_CLS_BAL_MTD_LCY,ORIG_CLS_BAL_MTD_LCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (145282, 'ORIG_CLS_BAL_MTD_FCY,ORIG_CLS_BAL_MTD_FCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (145388, 'DSBR_AMT_MTD_LCY,DSBR_AMT_MTD_LCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (145486, 'CDR_DT_DIM_ID,CDR_DT_DIM_ID,FNC_SVC_AR_ANL_FCT_FA'),
#  (145578, 'PREPYMT_AMT_MTD_LCY,PREPYMT_AMT_MTD_LCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (145682, 'PREPYMT_AMT_MTD_FCY,PREPYMT_AMT_MTD_FCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (145786, 'CLS_BAL_MTD_LCY,CLS_BAL_MTD_LCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (145882, 'CLS_BAL_MTD_FCY,CLS_BAL_MTD_FCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (145978, 'CLS_BAL_WTD_LCY,CLS_BAL_WTD_LCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (146074, 'CLS_BAL_WTD_FCY,CLS_BAL_WTD_FCY,FNC_SVC_AR_ANL_FCT_FA'),
#  (146170, 'AC_AR_ID,AC_AR_ID,AC_AR_DIM'),
#  (146255,
#   "(FCT.CDR_DT_DIM_ID = to_number(TO_CHAR((TO_DATE(#pDate#, 'yyyymmdd') - 1), "
#   "'yyyymmdd')) AND FCT.SRO_DIM_ID = 7)"),
#  (146466, '0'),
#  (146544, '0'),
#  (146598, '2000'),
#  (146650, '0'),
#  (146720, '2000'),
#  (146777, '1'),
#  (146840, '0'),
#  (146916, '0'),
#  (146971, '0'),
#  (147033, '0'),
#  (147109, '1'),
#  (147199, '0'),
#  (147280, '0'),
#  (147359, '0'),
#  (161377, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (161469, '#PS_ORA_CONN_DMT.Username#'),
#  (161555, '#PS_ORA_CONN_DMT.Password#'),
#  (161652, '0'),
#  (161712, '11g'),
#  (161792, '0'),
#  (161855, '1'),
#  (161920, 'TWT_FCA_ANL_FCT_FA_LST_DY'),
#  (161980, '0'),
#  (162047, '0'),
#  (162126, '3'),
#  (162178, '1'),
#  (162216, '1'),
#  (162301, '1'),
#  (162387, '0'),
#  (162441, '2000'),
#  (162516, '2000'),
#  (162577, '0'),
#  (162647, '0'),
#  (162720, '1'),
#  (162788, '1'),
#  (162882, '0'),
#  (162962, '0'),
#  (163043, '0'),
#  (163122, '0'),
#  (163184, '0'),
#  (172552, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (172644, '#PS_ORA_CONN_DMT.Username#'),
#  (172730, '#PS_ORA_CONN_DMT.Password#'),
#  (172827, '0'),
#  (172887, '11g'),
#  (172953, '0'),
#  (173002, '0'),
#  (173058, '0'),
#  (173138,
#   'with TMP_MAX_BY_CST as\n'
#   '(\n'
#   'SELECT\n'
#   '    CST_ID\n'
#   "    ,CASE WHEN T.MUD IN ('OD', 'LN') THEN 1 WHEN T.MUD = 'CARD' THEN 2 END "
#   'CST_MUD\n'
#   '    ,MAX(COALESCE(X7.VAL, T.ADJ_FNC_ST_CODE))        CST_FNC_ST_CODE\n'
#   'FROM TWT_FNC_SVC_AR_FCT_FA T\n'
#   'LEFT JOIN TBL_XLS_AR_TO_SBV_FNC_ST X7  ON T.AR_UNQ_ID = X7.KEY AND '
#   "X7.STATUS = 'A' AND X7.EFF_DT <= #pdate# AND X7.END_DT > #pdate#\n"
#   "GROUP BY T.CST_ID, CASE WHEN T.MUD IN ('OD', 'LN') THEN 1 WHEN T.MUD = "
#   "'CARD' THEN 2 END\n"
#   '),\n'
#   'TMP_MAX_BY_CST2 as\n'
#   '(\n'
#   'SELECT\n'
#   '    CST_ID\n'
#   '    ,MAX(COALESCE(X7.VAL, T.ADJ_FNC_ST_CODE))        CST_FNC_ST_CODE\n'
#   'FROM TWT_FNC_SVC_AR_FCT_FA T\n'
#   'LEFT JOIN TBL_XLS_AR_TO_SBV_FNC_ST X7  ON T.AR_UNQ_ID = X7.KEY AND '
#   "X7.STATUS = 'A' AND X7.EFF_DT <= #pdate# AND X7.END_DT > #pdate#\n"
#   'GROUP BY T.CST_ID\n'
#   ')\n'
#   'SELECT DISTINCT \t\n'
#   '\t T.AC_AR_ID\n'
#   '\t,T.CST_ID\n'
#   '\t,T.LOAN_PPS_CODE\n'
#   '\t,COALESCE(X10.VAL, T.PD_CODE)\tPD_CODE\n'
#   '\t,T.RLTNP_OFCR_ID\n'
#   '\t,T.IDY_CODE\n'
#   '\t,T.LDGR_ACG_ID\n'
#   '\t,COALESCE(X1.VAL,X2.VAL,T.ADJ_OU_CODE) \tADJ_OU_CODE\n'
#   '\t,COALESCE(X6.VAL, T.ADJ_CCY_CODE) \t\tADJ_CCY_CODE\n'
#   '\t,COALESCE(X3.VAL, X4.VAL, X5.VAL)\t\tADJ_LOB_CODE\n'
#   '\t,T1.CST_FNC_ST_CODE\n'
#   '\t,COALESCE(X7.VAL, T.ADJ_FNC_ST_CODE)\tADJ_FNC_ST_CODE\n'
#   '\t,NVL(X8.VAL,T1.CST_FNC_ST_CODE)\t\t\tMIS_ADJ_FNC_ST_CODE\n'
#   "\t,GREATEST(nvl(X9.VAL, 'NORM'), NVL(X8.VAL, T1.CST_FNC_ST_CODE))\t"
#   'FNL_FNC_ST_CODE\n'
#   '\t,T.FNC_ST_TP_CODE\n'
#   '\t,T.CG_SEG\n'
#   '\t,T.MSEG\n'
#   '\t,T.PY_OFF_BFR_DUE_DT_F\n'
#   '\t,T.INT_RATE\n'
#   "\t,'NORM'\t\t\t\t\t\t\t\t\t\t\t\tSRO_CODE\n"
#   '\t,DECODE(X11.VAL,NULL,0,1)\t\t\t\t\t\t\tPB_MISCODE_F --EDIT 20200526\n'
#   "\t,DECODE(X12.VAL,'Y',1,0)\t\t\t\t\t\t\tPB_CST_F\n"
#   '\t,T.PYMT_CARD_ID\n'
#   '\t,T.MUD\n'
#   '\t,X5.VAL\t\t\t\t\t\t\t\t\t\t\t\tLOB_CODE\n'
#   '\t,NVL(X2.VAL,T.ADJ_OU_CODE)\t\t\t\t\t\t\tOU_CODE\n'
#   '\t,X9.VAL\t\t\t\t\t\t\t\t\t\t\t\tCIC_FNC_ST_CODE\n'
#   '\t,T.ADJ_CCY_CODE\t\t\t\t\t\t\t\t\t\tCCY_CODE\n'
#   '\t,T2.CST_FNC_ST_CODE \t\t                        OVRL_CST_FNC_ST_CODE\n'
#   '\t,NVL(X8.VAL,T2.CST_FNC_ST_CODE) \t                '
#   'OVRL_MIS_ADJ_FNC_ST_CODE\n'
#   "\t,GREATEST(NVL(X9.VAL, 'NORM'), NVL(X8.VAL,T2.CST_FNC_ST_CODE)) \t\t    "
#   'OVRL_FNL_FNC_ST_CODE\n'
#   "\t,CASE WHEN COALESCE(X1.VAL,X2.VAL,T.ADJ_OU_CODE) = '444' THEN 0\n"
#   "\t\tWHEN COALESCE(X10.VAL, T.PD_CODE) = 'CL00' THEN 0\n"
#   "\t\tWHEN T.MUD = 'LN' AND T.CLS_BAL_FCY < 0 THEN 0\n"
#   '\t\tELSE nvl(T.CLS_BAL_FCY, 0)\n'
#   '\tEND\t\t\t\t\t\t\t\t\t\t\t\t\tCLS_BAL_FCY\n'
#   "\t,CASE WHEN COALESCE(X1.VAL,X2.VAL,T.ADJ_OU_CODE) = '444' THEN 0\n"
#   "\t\tWHEN COALESCE(X10.VAL, T.PD_CODE) = 'CL00' THEN 0\n"
#   "\t\tWHEN T.MUD = 'LN' AND T.CLS_BAL_LCY < 0 THEN 0\n"
#   '\t\tELSE nvl(T.CLS_BAL_LCY, 0)\n'
#   '\tEND\t\t\t\t\t\t\t\t\t\t\t\t\tCLS_BAL_LCY\t\n'
#   '\t,nvl(T.LQD_AMT_FCY, 0)\t\t\t\t\t\t\t\tLQD_AMT_FCY\n'
#   '\t,nvl(T.LQD_AMT_LCY, 0)\t\t\t\t\t\t\t\tLQD_AMT_LCY\n'
#   '\t,nvl(T.DSBR_AMT_FCY, 0)\t\t\t\t\t\t\t\tDSBR_AMT_FCY\n'
#   '\t,nvl(T.DSBR_AMT_LCY, 0)\t\t\t\t\t\t\t\tDSBR_AMT_LCY\n'
#   '\t,nvl(T.PREPYMT_AMT_FCY, 0)\t\t\t\t\t\t\tPREPYMT_AMT_FCY\n'
#   '\t,nvl(T.PREPYMT_AMT_LCY, 0)\t\t\t\t\t\t\tPREPYMT_AMT_LCY\n'
#   '\t--add new 20200516\t\t\n'
#   '\t,nvl(T.ORIG_CLS_BAL_FCY, 0)\t\t\t\t\t\t\tORIG_CLS_BAL_FCY\n'
#   '\t,nvl(T.ORIG_CLS_BAL_LCY, 0) \t\t\t\t\t\tORIG_CLS_BAL_LCY\n'
#   '\t,T.PD_CODE\t\t\t\t\t\t\t\t\t\t\tORIG_PD_CODE\n'
#   '\t,COALESCE(X11.VAL,X1.VAL,X2.VAL,T.ADJ_OU_CODE)\t\tMIS1_OU_CODE\n'
#   '-- Add new luc.luu\t\n'
#   '\t,nvl(T.FEE_INCM_LCY,0) FEE_INCM_LCY\n'
#   '\t,nvl(T.LMT_AMT,0) TOT_LMT_AMT\n'
#   '\t,nvl(T.TOT_AVL_LMT_AMT,0) TOT_AVL_LMT_AMT\n'
#   '\t,nvl(T.PNP_ARS,0) PNP_ARS\n'
#   '\t,nvl(T.INT_ARS,0) INT_ARS\n'
#   '\t,nvl(T.CLS_UTLZ_AMT_FCY,0) CLS_UTLZ_AMT_FCY\n'
#   '\t,nvl(T.PNP_DUE_AMT,0) PNP_DUE_AMT\n'
#   '\t,nvl(T.INT_DUE_AMT,0) INT_DUE_AMT\n'
#   '\t,DLQ_CNT\n'
#   '\t,NVL(T.TOT_DSBR_AMT_FCY,0) TOT_DSBR_AMT_FCY\n'
#   '\t,T.RPRG_OU_CODE\n'
#   '\t,t.INTERIM_INT\n'
#   ',T.NOD_PAST_DUE\n'
#   'FROM TWT_FNC_SVC_AR_FCT_FA T\n'
#   'LEFT JOIN TBL_XLS_AR_TO_OU_NEW X1 \t\tON T.AR_UNQ_ID = X1.KEY AND X1.STATUS '
#   "= 'A' AND X1.EFF_DT <= #pdate# AND X1.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_OU_OLD_TO_OU_NEW X2 \tON T.ADJ_OU_CODE = X2.KEY AND '
#   "X2.STATUS = 'A' AND X2.EFF_DT <= #pdate# AND X2.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_AR_TO_LINE X3\t\t\tON T.AR_UNQ_ID = X3.KEY AND X3.STATUS '
#   "= 'A' AND X3.EFF_DT <= #pdate# AND X3.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_OU_TO_LINE X4\t\t\tON COALESCE(X1.VAL, X2.VAL, '
#   "T.ADJ_OU_CODE) = X4.KEY AND X4.STATUS = 'A' AND X4.EFF_DT <= #pdate# AND "
#   'X4.END_DT > #pdate#\n'
#   'LEFT JOIN TBL_XLS_CG_SEGMNT_TO_LINE X5\tON T.CG_SEG = X5.KEY_ID AND '
#   "X5.STATUS = 'A' AND X5.EFF_DT <= #pdate# AND X5.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_AR_TO_CCY_NEW X6\t\tON T.AR_UNQ_ID = X6.KEY AND X6.STATUS '
#   "= 'A' AND X6.EFF_DT <= #pdate# AND X6.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_AR_TO_SBV_FNC_ST X7\tON T.AR_UNQ_ID = X7.KEY AND '
#   "X7.STATUS = 'A' AND X7.EFF_DT <= #pdate# AND X7.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_AR_TO_MIS_FNC_ST X8  ON T.AR_UNQ_ID = X8.KEY AND '
#   "X8.STATUS = 'A' AND X8.EFF_DT <= #pdate# AND X8.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_AR_TO_PD_NEW X10\t\tON T.AR_UNQ_ID = X10.KEY AND '
#   "X10.STATUS = 'A' AND X10.EFF_DT <= #pdate# AND X10.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_CST_TO_AF_CIC X9    \tON T.CST_ID = X9.KEY_ID AND '
#   "X9.STATUS = 'A' AND X9.EFF_DT <= #pdate# AND X9.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_MISCODE_PB X11\t\tON T.EMPE_NBR = X11.KEY AND X11.STATUS '
#   "= 'A' AND X11.EFF_DT <= #pdate# AND X11.END_DT > #pdate#\n"
#   'LEFT JOIN TBL_XLS_CST_PB X12\t\t\tON T.CST_ID = X12.KEY_ID AND X12.STATUS = '
#   "'A' AND X12.EFF_DT <= #pdate# AND X12.END_DT > #pdate#\n"
#   'LEFT JOIN TMP_MAX_BY_CST T1 \t\t\tON T1.CST_ID = T.CST_ID AND CASE WHEN '
#   "T.MUD IN ('OD', 'LN') THEN 1 WHEN T.MUD = 'CARD' THEN 2 END = T1.CST_MUD\n"
#   'LEFT JOIN TMP_MAX_BY_CST2 T2 \t\t\tON T2.CST_ID = T.CST_ID'),
#  (178208, '0'),
#  (178419, '0'),
#  (178497, '0'),
#  (178551, '2000'),
#  (178603, '0'),
#  (178673, '2000'),
#  (178730, '1'),
#  (178793, '0'),
#  (178869, '0'),
#  (178924, '0'),
#  (178986, '0'),
#  (179062, '1'),
#  (179152, '0'),
#  (179233, '0'),
#  (179312, '0'),
#  (226315, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (226407, '#PS_ORA_CONN_DMT.Username#'),
#  (226493, '#PS_ORA_CONN_DMT.Password#'),
#  (226590, '0'),
#  (226650, '11g'),
#  (226730, '0'),
#  (226793, '1'),
#  (226858, 'TWT_FNC_SVC_AR_ANL_FCT_FA'),
#  (226918, '0'),
#  (226985, '0'),
#  (227064, '3'),
#  (227116, '1'),
#  (227154, '1'),
#  (227239, '1'),
#  (227325, '0'),
#  (227379, '2000'),
#  (227454, '2000'),
#  (227515, '0'),
#  (227585, '0'),
#  (227658, '1'),
#  (227726, '1'),
#  (227820, '0'),
#  (227900, '0'),
#  (227981, '0'),
#  (228060, '0'),
#  (228122, '0'),
#  (239496, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (239588, '#PS_ORA_CONN_SOR.Username#'),
#  (239674, '#PS_ORA_CONN_SOR.Password#'),
#  (239771, '0'),
#  (239831, '11g'),
#  (239897, '0'),
#  (239946, '0'),
#  (240002, '0'),
#  (240082,
#   'select\n'
#   'chg.AC_AR_ID\n'
#   ",decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_FCY*CHG.ADJ_BAL), "
#   'CLS_VAL_BAL_FCY*CHG.ADJ_BAL)\tCLS_BAL_FCY   \n'
#   ",decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_LCY*CHG.ADJ_BAL), "
#   'CLS_VAL_BAL_LCY*CHG.ADJ_BAL)\tCLS_BAL_LCY\n'
#   ',TVR.LQD_AMT_FCY                               \t\t\tLQD_AMT_FCY\n'
#   ',TVR.LQD_AMT_LCY                       \t    \t\t\tLQD_AMT_LCY\n'
#   ',TVR.DSBR_AMT_TDY_FCY                                   DSBR_AMT_FCY\n'
#   ',TVR.DSBR_AMT_TDY                                      \tDSBR_AMT_LCY\n'
#   ',TVR.PREPYMT_AMT\t                                    PREPYMT_AMT_FCY\n'
#   ',TVR.PREPYMT_AMT*TVR.EXG_RATE_TO_LCL_CCY\t            PREPYMT_AMT_LCY\n'
#   ',TVR.PY_OFF_BFR_DUE_DT_F                              \t'
#   'PY_OFF_BFR_DUE_DT_F\n'
#   ",decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', \n"
#   '\t\tCOALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, '
#   'CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100))))\t    ADJ_FNC_ST_CODE '
#   '--NHOM NO\n'
#   ",CASE WHEN decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', \n"
#   '\t\tCOALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, '
#   "CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100)))) <> 'NORM' AND PNP_ARS + "
#   "INT_ARS > 0 THEN 'THUC_TE' \n"
#   "      WHEN decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', \n"
#   '\t\tCOALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, '
#   "CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100)))) <> 'NORM' AND PNP_ARS + "
#   "INT_ARS = 0 THEN 'THU_THACH'\n"
#   ' END                                        \t\t\tFNC_ST_TP_CODE\n'
#   '-- Add new luc.luu\n'
#   ',DLQ.PNP_ARS\n'
#   ',DLQ.INT_ARS\n'
#   ',DLQ.NOD_PAST_DUE\n'
#   ',TVR.DSBR_AMT_LTD TOT_DSBR_AMT_FCY\n'
#   ',TVR.INTERIM_INT\n'
#   ',CASE WHEN DLQ.PNP_PAST_DUE_DT <= nvl(DLQ.INT_PAST_DUE_DT,99991231) AND '
#   'PAST_DUE_F = 1\n'
#   '\t  AND  DLQ.PNP_PAST_DUE_DT IS NOT NULL \n'
#   '\t  THEN '
#   "MONTHS_BETWEEN(Trunc(to_date(#pdate#,'yyyymmdd'),'MONTH'),Trunc(to_date(DLQ.PNP_PAST_DUE_DT,'yyyymmdd'),'MONTH')) \n"
#   '\t  WHEN PAST_DUE_F = 1 AND DLQ.INT_PAST_DUE_DT <= '
#   'nvl(DLQ.PNP_PAST_DUE_DT,99991231) \n'
#   '\t  AND  DLQ.INT_PAST_DUE_DT IS NOT NULL \n'
#   '\t  THEN '
#   "MONTHS_BETWEEN(Trunc(to_date(#pdate#,'yyyymmdd'),'MONTH'),Trunc(to_date(DLQ.INT_PAST_DUE_DT,'yyyymmdd'),'MONTH'))\n"
#   '\t  ELSE 0 END DLQ_CNT\n'
#   ",decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_FCY), CLS_VAL_BAL_FCY) "
#   'ORIG_CLS_BAL_FCY\n'
#   ",decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_LCY), CLS_VAL_BAL_LCY) "
#   'ORIG_CLS_BAL_LCY\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG chg\n'
#   'LEFT JOIN AR_DLQ_SMY DLQ ON ac_AR_ID = DLQ.AR_ID AND DLQ.MSR_PRD_ID = '
#   '#pDate#\n'
#   'LEFT JOIN TWT_AR_TVR_SMY_DAILY TVR ON ac_AR_ID = TVR.AR_ID AND '
#   'TVR.MSR_PRD_ID = #pDate#\n'
#   'LEFT JOIN (SELECT ARF.AR_ID, ARF.EFF_DT, ARF.END_DT, CD.CL_CODE\n'
#   '\tFROM AR_FNC_ST ARF\n'
#   '\tLEFT JOIN CV CD ON CD.CL_ID = ARF.AR_FNC_ST_TP_ID\n'
#   "      WHERE ARF.AR_FNC_ST_SCM_ID = 'FF2F2563FA9BFED792EDC3A35EFDEE92') ARF "
#   'ON AC_AR_ID = ARF.AR_ID \n'
#   '\t  AND ARF.EFF_DT <= LAST_EFF_DT AND ARF.END_DT > LAST_EFF_DT --LU_CV: '
#   "'AR_FNC_ST_SCM', 'USR_DFND_ST'"),
#  (242888, '0'),
#  (243099, '0'),
#  (243177, '0'),
#  (243231, '2000'),
#  (243283, '0'),
#  (243353, '2000'),
#  (243410, '1'),
#  (243473, '0'),
#  (243549, '0'),
#  (243604, '0'),
#  (243666, '0'),
#  (243742, '1'),
#  (243832, '0'),
#  (243913, '0'),
#  (243992, '0'),
#  (367157, '1'),
#  (367203, '11'),
#  (367260, '1.0'),
#  (367321, '-1'),
#  (367367, '0'),
#  (367442, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (367534, '#PS_ORA_CONN_SOR.Username#'),
#  (367620, '#PS_ORA_CONN_SOR.Password#'),
#  (367717, '0'),
#  (367777, '11g'),
#  (367843, '0'),
#  (367905, '0'),
#  (367961, '0'),
#  (368041,
#   'SELECT AC_AR.AC_AR_ID\n'
#   "\t,nvl(max(decode(AR_AVY.CL_CODE, 'PRINCIPAL', DUE_AMT)), 0) PNP_DUE_AMT "
#   '--GOC DEN HAN\n'
#   "\t,nvl(max(decode(AR_AVY.CL_CODE, 'MAIN_INT', DUE_AMT)), 0) INT_DUE_AMT "
#   '--LAI DEN HAN\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR\n'
#   'LEFT JOIN (\n'
#   '\tSELECT AR_AVY.*\n'
#   '\t\t,CV.CL_CODE\n'
#   '\tFROM AR_AVY\n'
#   '\tJOIN CV ON AR_AVY.AVY_TP_ID = CV.CL_ID\n'
#   "\t\tAND CV.CL_SCM_CODE = 'AVY_TP'\n"
#   "\t\tAND AR_AVY.SRC_STM_ID = '92D4125CCD5B1BDF51F47FBCCDBBBF27' -- "
#   'FCC.CLTB_ACCOUNT_SCHEDULES\n'
#   '\t\tAND CV.CL_CODE IN (\n'
#   "\t\t\t'PRINCIPAL'\n"
#   "\t\t\t,'MAIN_INT'\n"
#   '\t\t\t)\n'
#   '\t) AR_AVY ON AC_AR.AC_AR_ID = AR_AVY.AR_ID\n'
#   'LEFT JOIN (\n'
#   '\tSELECT AVY_SHD.AR_AVY_ID\n'
#   '\t\t,SUM(nvl(AVY_SHD.SHD_AMT, 0) - nvl(AVY_SHD.ACT_AMT, 0)) DUE_AMT --DEN '
#   'HAN\n'
#   '\tFROM AR_AVY_SHD_ITM AVY_SHD\n'
#   '\tWHERE AVY_SHD.EFF_DT <= #pDate#\n'
#   '\t\tAND AVY_SHD.END_DT > #pDate#\n'
#   '\t\tAND AVY_SHD.EXPC_END_DT <= #pDate#\n'
#   '\t\tAND AVY_SHD.SHD_AMT > AVY_SHD.ACT_AMT\n'
#   '\tGROUP BY AVY_SHD.AR_AVY_ID\n'
#   '\t) AVY_SHD ON AR_AVY.AR_AVY_ID = AVY_SHD.AR_AVY_ID\n'
#   'GROUP BY AC_AR.AC_AR_ID'),
#  (369024, '0'),
#  (369235, '0'),
#  (369313, '0'),
#  (369367, '2000'),
#  (369419, '0'),
#  (369489, '2000'),
#  (369546, '1'),
#  (369609, '0'),
#  (369685, '0'),
#  (369740, '0'),
#  (369802, '0'),
#  (369878, '1'),
#  (369968, '0'),
#  (370049, '0'),
#  (370128, '0'),
#  (377129, '1'),
#  (377175, '11'),
#  (377232, '1.0'),
#  (377293, '-1'),
#  (377339, '0'),
#  (377414, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (377506, '#PS_ORA_CONN_SOR.Username#'),
#  (377592, '#PS_ORA_CONN_SOR.Password#'),
#  (377689, '0'),
#  (377749, '11g'),
#  (377815, '0'),
#  (377864, '0'),
#  (377920, '0'),
#  (378000,
#   '--LOAN\n'
#   'SELECT LOAN.AC_AR_ID, SUM(TOT_AVL_LMT_AMT) TOT_AVL_LMT_AMT\n'
#   'FROM (SELECT AC_AR.AC_AR_ID\n'
#   '\t,nvl(RI_VAL.CLT_VALT - RI_VAL.LMT_CTB, 0) TOT_AVL_LMT_AMT\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR\n'
#   'LEFT JOIN AR_X_RI_RLTNP AR_X_RI ON AR_X_RI.AR_ID = AC_AR.AC_AR_ID\n'
#   '\tAND AR_X_RI.EFF_DT <= AC_AR.LAST_EFF_DT\n'
#   '\tAND AR_X_RI.END_DT > AC_AR.LAST_EFF_DT\n'
#   "\tAND AR_X_RI.AR_X_RI_RLTNP_TP_ID = 'B6C71A2D532689A626795C8D4B67A75D' -- "
#   'LOAN_AR_X_COLATERAL\n'
#   "\tAND AR_X_RI.SRC_STM_ID = '0A173E8726B6D97003B5EE634C0CCA92' -- "
#   'FCC.CLTB_ACC_COLL_LINK_DTLS\n'
#   'LEFT JOIN RI ON AR_X_RI.RI_ID = RI.RI_ID and RI.SRC_STM_ID = '
#   "'BB35A878C33FFBF19ADA056E5449DAAF' --FCC.GETM_COLLAT\n"
#   'LEFT JOIN (\n'
#   '\tSELECT RI_VAL.RI_ID\n'
#   "\t\t,NVL(MAX(DECODE(CL_CODE, 'CLT_VALT', RI_VAL.VAL_AMT)), 0) CLT_VALT\n"
#   "\t\t,NVL(MAX(DECODE(CL_CODE, 'LMT_CTB', RI_VAL.VAL_AMT)), 0) LMT_CTB\n"
#   '\tFROM RI_VAL\n'
#   '\tJOIN CV ON RI_VAL.RI_VAL_TP_ID = CV.CL_ID\n'
#   "\t\tAND CV.CL_SCM_CODE = 'RI_VAL_TP'\n"
#   '\t\tAND CV.CL_CODE IN (\n'
#   "\t\t\t'CLT_VALT'\n"
#   "\t\t\t,'LMT_CTB'\n"
#   '\t\t\t)\n'
#   '\tWHERE RI_VAL.EFF_DT <= #pDate#\n'
#   '\t\tAND RI_VAL.END_DT > #pDate#\n'
#   '\tGROUP BY RI_VAL.RI_ID\n'
#   '\t) RI_VAL ON RI_VAL.RI_ID = RI.RI_ID\n'
#   'LEFT JOIN RI_X_UDF_RLTNP RI_X_UDF ON RI_X_UDF.RI_ID = RI.RI_ID\n'
#   '\tAND RI_X_UDF.EFF_DT <= #pDate#\n'
#   '\tAND RI_X_UDF.END_DT > #pDate#\n'
#   'LEFT JOIN (\n'
#   '\tSELECT RI_X_CL.*\n'
#   '\t\t,CV.CL_NM\n'
#   '\tFROM RI_X_CL_RLTNP RI_X_CL\n'
#   '\tJOIN CV ON RI_X_CL.CL_ID = CV.CL_ID\n'
#   '\t\tAND RI_X_CL.EFF_DT <= #pDate#\n'
#   '\t\tAND RI_X_CL.END_DT > #pDate#\n'
#   "\tWHERE RI_X_CL.RI_X_CL_RLTNP_TP_ID = '1AD160750012C416E42B551CC5CA4A5F' -- "
#   "'RI_X_COLL_CGY\n"
#   '\t) COLL_CGY ON COLL_CGY.RI_ID = RI.RI_ID\n'
#   'LEFT JOIN AR_LC_ST LC_ST ON LC_ST.AR_ID = AR_X_RI.AR_ID\n'
#   "\tAND LC_ST.SRC_STM_ID = '85425375A0630AA9C05A16D7D3420345' -- "
#   'FCC.CLTB_ACCOUNT_APPS_MASTER\n'
#   "\tAND LC_ST.AR_LC_ST_SCM_ID = '6B7D2ED561F31655BADF9F232E792DE2' -- TYPE: "
#   'ACCOUNT_STATUS\n'
#   '\tAND LC_ST.EFF_DT <= AC_AR.LAST_EFF_DT\n'
#   '\tAND LC_ST.END_DT > AC_AR.LAST_EFF_DT\n'
#   "WHERE RI_X_UDF.UDF_ID = '890E57353540716EA2E539E6A39DBB33' -- GEDCOLLT.TCTD "
#   'PHAT HANH GTCG\n'
#   "\tAND RI_X_UDF.UDF_VAL <> 'KHAC'\n"
#   "\tAND RI_LC_ST_TP_ID = '4C32D5E60A5794603A48F0E1AC950315' -- 'RECORD_STAT = "
#   "O'\n"
#   '\tAND LC_ST.AR_LC_ST_TP_ID IN (\n'
#   "\t\t'7D108472968DF6F6A56D5BDFC01488A9'\n"
#   "\t\t,'06CD0B184A47E6CEB56653555A20950F'\n"
#   "\t\t) -- ACCOUNT_STATUS IN ('A', 'H')\n"
#   '\tAND COLL_CGY.CL_NM IN (\n'
#   "\t\t'121101'\n"
#   "\t\t,'121102'\n"
#   "\t\t,'121103'\n"
#   "\t\t,'121991'\n"
#   "\t\t,'121992'\n"
#   "\t\t,'121993'\n"
#   "\t\t,'122101'\n"
#   "\t\t,'122102'\n"
#   "\t\t,'122201'\n"
#   "\t\t,'122202'\n"
#   "\t\t,'122203'\n"
#   "\t\t,'123101'\n"
#   "\t\t,'123102'\n"
#   "\t\t,'123201'\n"
#   "\t\t,'123202'\n"
#   "\t\t,'123301'\n"
#   "\t\t,'123302'\n"
#   "\t\t,'124001'\n"
#   "\t\t,'124002'\n"
#   "\t\t,'124003'\n"
#   "\t\t,'125001'\n"
#   "\t\t,'125002'\n"
#   "\t\t,'125003'\n"
#   "\t\t,'126001'\n"
#   "\t\t,'126002'\n"
#   "\t\t,'126003'\n"
#   "\t\t,'129991'\n"
#   "\t\t,'129992'\n"
#   "\t\t,'129993'\n"
#   "\t\t,'170301'\n"
#   "\t\t,'170302'\n"
#   '\t\t)) LOAN\n'
#   'GROUP BY LOAN.AC_AR_ID\n'
#   '\n'
#   'UNION ALL\n'
#   '\n'
#   '--OD\n'
#   'SELECT AC_AR.AC_AR_ID\n'
#   '\t,nvl(CASE \n'
#   '\t\t\tWHEN AR_X_LMT.LMT_AMT > 0\n'
#   '\t\t\t\tTHEN (\n'
#   '\t\t\t\t\t\tCASE \n'
#   '\t\t\t\t\t\t\tWHEN NVL(TVR_SMY.CLS_VAL_BAL_LCY, 0) < 0\n'
#   '\t\t\t\t\t\t\t\tTHEN AR_X_LMT.LMT_AMT + NVL(TVR_SMY.CLS_VAL_BAL_LCY, 0)\n'
#   '\t\t\t\t\t\t\tELSE AR_X_LMT.LMT_AMT\n'
#   '\t\t\t\t\t\t\tEND\n'
#   '\t\t\t\t\t\t)\n'
#   '\t\t\tELSE C.TOT_AVL_LMT_AMT\n'
#   '\t\t\tEND, 0) TOT_AVL_LMT_AMT\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR\n'
#   'LEFT JOIN AR_X_LMT_TP_RLTNP AR_X_LMT ON AC_AR.AC_AR_ID = AR_X_LMT.AR_ID\n'
#   'LEFT JOIN AR_TVR_SMY TVR_SMY ON AC_AR.AC_AR_ID = TVR_SMY.AR_ID\n'
#   '\tAND TVR_SMY.MSR_PRD_ID = #pDate#\n'
#   'LEFT JOIN (\n'
#   '\tSELECT AR_X_AR.SBJ_AR_ID AR_ID\n'
#   '\t\t,CR_USG_SMY.CLS_AVL_AMT TOT_AVL_LMT_AMT\n'
#   '\tFROM AR_X_AR_RLTNP AR_X_AR\n'
#   '\tLEFT JOIN AR_CR_USG_SMY CR_USG_SMY ON AR_X_AR.OBJ_AR_ID = '
#   'CR_USG_SMY.AR_ID\n'
#   "\tWHERE AR_X_AR.SRC_STM_ID = 'A859AEF31E787D7AAA50F314F87DE330'\n"
#   '\t\tAND CR_USG_SMY.MSR_PRD_ID = #pDate#\n'
#   '\t\tAND AR_X_AR.EFF_DT <= #pDate#\n'
#   '\t\tAND AR_X_AR.END_DT > #pDate#\n'
#   "\t\tAND AR_X_AR.AR_X_AR_RLTNP_TP_ID = 'E9BCF51A07832895CE3CAFED32695B4D'\n"
#   '\t) C ON AC_AR.AC_AR_ID = C.AR_ID\n'
#   "WHERE AC_AR.MUD = 'OD'\n"
#   '\tAND AR_X_LMT.EFF_DT <= AC_AR.LAST_EFF_DT\n'
#   '\tAND AR_X_LMT.END_DT > AC_AR.LAST_EFF_DT\n'
#   "\tAND AR_X_LMT.LMT_TP_ID = 'B00397055F38C5365C64B45D8CD5DFE3'"),
#  (381783, '0'),
#  (381994, '0'),
#  (382072, '0'),
#  (382126, '2000'),
#  (382178, '0'),
#  (382248, '2000'),
#  (382305, '1'),
#  (382368, '0'),
#  (382444, '0'),
#  (382499, '0'),
#  (382561, '0'),
#  (382637, '1'),
#  (382727, '0'),
#  (382808, '0'),
#  (382887, '0'),
#  (463539, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (463631, '#PS_ORA_CONN_SOR.Username#'),
#  (463717, '#PS_ORA_CONN_SOR.Password#'),
#  (463814, '0'),
#  (463874, '11g'),
#  (463940, '0'),
#  (463989, '0'),
#  (464045, '0'),
#  (464125,
#   '--LOAN\n'
#   'SELECT AC_AR_ID, SUM(LMT_AMT) LMT_AMT\n'
#   'FROM (\n'
#   'SELECT AC_AR.AC_AR_ID\n'
#   '\t,nvl(AR_X_AR.LMT_AMT, 0) LMT_AMT\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR\n'
#   'JOIN AR_X_AR_RLTNP AR_X_AR ON AC_AR.AC_AR_ID = AR_X_AR.SBJ_AR_ID\n'
#   '\tAND AR_X_AR.EFF_DT <= #pdate#\n'
#   '\tAND AR_X_AR.END_DT > #pdate#\n'
#   "\tAND AR_X_AR.SRC_STM_ID = '0A173E8726B6D97003B5EE634C0CCA92' "
#   '--FCC.CLTB_ACC_COLL_LINK_DTLS\n'
#   "\tAND AR_X_AR.AR_X_AR_RLTNP_TP_ID IN ('48AD3C9EF52018E228A295F9A93E5DF4', "
#   "'F3B20F07E2D8DDE866BED28D24F7FCE4') --'AR_X_POOL_AR','AR_X_FACI_AR'\n"
#   "WHERE AC_AR.MUD = 'LN'\n"
#   'UNION ALL\n'
#   'SELECT AC_AR.AC_AR_ID\n'
#   '\t,nvl(AR_X_RI.LMT_AMT, 0) LMT_AMT\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR\n'
#   'JOIN (\n'
#   '\tSELECT AR_X_RI.AR_ID\n'
#   '\t\t,AR_X_RI.EFF_DT\n'
#   '\t\t,AR_X_RI.END_DT\n'
#   '\t\t,AR_X_RI.LMT_AMT\n'
#   '\tFROM AR_X_RI_RLTNP AR_X_RI\n'
#   '\tWHERE AR_X_RI.EFF_DT <= #pdate#\n'
#   '\t\tAND AR_X_RI.END_DT > #pdate#\n'
#   "\t\tAND AR_X_RI.SRC_STM_ID = '0A173E8726B6D97003B5EE634C0CCA92'\n"
#   '\t) AR_X_RI ON AR_X_RI.AR_ID = AC_AR.AC_AR_ID\n'
#   "WHERE AC_AR.MUD = 'LN'\n"
#   '\tAND AR_X_RI.EFF_DT <= #pdate#\n'
#   '\tAND AR_X_RI.END_DT > #pdate#\n'
#   ') GROUP BY AC_AR_ID\n'
#   '--OD\n'
#   'UNION ALL\n'
#   'SELECT A.AC_AR_ID\n'
#   '\t,NVL(LMT.LMT_AMT, 0) LMT_AMT\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG A\n'
#   'LEFT JOIN AR_X_LMT_TP_RLTNP LMT ON A.AC_AR_ID = LMT.AR_ID\n'
#   '\tAND LMT.EFF_DT <= #pdate#\n'
#   '\tAND LMT.END_DT > #pdate#\n'
#   "\tAND LMT.LMT_TP_ID = 'B00397055F38C5365C64B45D8CD5DFE3' --OD_LIMIT\n"
#   "WHERE A.MUD = 'OD'"),
#  (465489, '0'),
#  (465700, '0'),
#  (465778, '0'),
#  (465832, '2000'),
#  (465884, '0'),
#  (465954, '2000'),
#  (466011, '1'),
#  (466074, '0'),
#  (466150, '0'),
#  (466205, '0'),
#  (466267, '0'),
#  (466343, '1'),
#  (466433, '0'),
#  (466514, '0'),
#  (466593, '0'),
#  (511099, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (511191, '#PS_ORA_CONN_SOR.Username#'),
#  (511277, '#PS_ORA_CONN_SOR.Password#'),
#  (511374, '0'),
#  (511434, '11g'),
#  (511500, '0'),
#  (511549, '0'),
#  (511605, '0'),
#  (511685,
#   'SELECT AC_AR_ID, SUM(CLS_UTLZ_AMT_FCY) CLS_UTLZ_AMT_FCY\n'
#   'FROM (\n'
#   'SELECT AC_AR.AC_AR_ID , nvl(AR_X_AR.LINKED_AMT_FCY ,0) CLS_UTLZ_AMT_FCY \n'
#   '\t\t\tFROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR \n'
#   '\t\t\tLEFT JOIN (SELECT AR_X_AR.SBJ_AR_ID, AR_X_AR.EFF_DT, AR_X_AR.END_DT, '
#   'AR_X_AR.LINKED_AMT_FCY \n'
#   '\t\t\tFROM AR_X_AR_RLTNP AR_X_AR JOIN CV ON AR_X_AR.SRC_STM_ID = CV.CL_ID \n'
#   "                 AND CV.CL_SCM_CODE = 'SRC_STM' \n"
#   "                 AND CL_CODE = 'FCC.CLTB_ACC_COLL_LINK_DTLS'\n"
#   '                 WHERE AR_X_AR.EFF_DT <= #pdate# AND AR_X_AR.END_DT > '
#   '#pdate#) AR_X_AR \n'
#   '                 ON AC_AR.AC_AR_ID = AR_X_AR.SBJ_AR_ID  \n'
#   "where AC_AR.MUD = 'LN'     \n"
#   'AND AR_X_AR.EFF_DT <= AC_AR.LAST_EFF_DT AND AR_X_AR.END_DT > '
#   'AC_AR.LAST_EFF_DT\n'
#   'UNION\n'
#   'SELECT AC_AR.AC_AR_ID , nvl(AR_X_RI.RI_AMT ,0) CLS_UTLZ_AMT_FCY \n'
#   '\t\t\tFROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG AC_AR \n'
#   '\t\t\tLEFT JOIN (SELECT AR_X_RI.AR_ID, AR_X_RI.EFF_DT, AR_X_RI.END_DT, '
#   'AR_X_RI.RI_AMT \n'
#   '\t\t\tFROM AR_X_RI_RLTNP AR_X_RI\n'
#   '                 WHERE AR_X_RI.SRC_STM_ID = '
#   "'0A173E8726B6D97003B5EE634C0CCA92'\n"
#   '                 AND AR_X_RI.EFF_DT <= #pdate# AND AR_X_RI.END_DT > '
#   '#pdate#) AR_X_RI \n'
#   '                 ON AC_AR.AC_AR_ID = AR_X_RI.AR_ID  \n'
#   "where AC_AR.MUD = 'LN'     \n"
#   'AND AR_X_RI.EFF_DT <= AC_AR.LAST_EFF_DT AND AR_X_RI.END_DT > '
#   'AC_AR.LAST_EFF_DT)\n'
#   'GROUP BY AC_AR_ID'),
#  (513013, '0'),
#  (513224, '0'),
#  (513302, '0'),
#  (513356, '2000'),
#  (513408, '0'),
#  (513478, '2000'),
#  (513535, '1'),
#  (513598, '0'),
#  (513674, '0'),
#  (513729, '0'),
#  (513791, '0'),
#  (513867, '1'),
#  (513957, '0'),
#  (514038, '0'),
#  (514117, '0'),
#  (520411, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (520503, '#PS_ORA_CONN_SOR.Username#'),
#  (520589, '#PS_ORA_CONN_SOR.Password#'),
#  (520686, '0'),
#  (520746, '11g'),
#  (520812, '0'),
#  (520861, '0'),
#  (520917, '0'),
#  (520997,
#   'SELECT CHG.AC_AR_ID, \n'
#   'PST_ENTR.PST_ENTR_AMT_LCY FEE_INCM_LCY\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG CHG\n'
#   'LEFT JOIN PST_ENTR  ON PST_ENTR.REL_AR_ID = CHG.AC_AR_ID\n'
#   'AND PST_DT = #pdate#\n'
#   'LEFT JOIN AR_X_AU_RLTNP AR_X_AU ON CHG.AC_AR_ID = AR_X_AU.AR_ID \n'
#   "AND AR_X_AU.SRC_STM_ID = '85425375A0630AA9C05A16D7D3420345' -- "
#   'CLTB_ACCOUNT_APPS_MASTER\n'
#   'AND AR_X_AU.EFF_DT <= #pdate# AND AR_X_AU.END_DT > #pdate#\n'
#   'LEFT JOIN AU ON AU.AU_ID = AR_X_AU.AU_ID \n'
#   "WHERE CHG.PD_CODE IN ('C11M', 'C11S', 'M9P1', 'M9PM', 'M9PS', 'N9PS')\n"
#   "AND AU.ACG_STC_ITM_ID IN (select function_hash02('GL' || '|' || "
#   "'FCC.GLTM_GLMASTER', FIELD1) \n"
#   "from EXT_FCC_jrtb_parameters a where a.srv_id = 'GL023CB')\n"
#   "AND ACG_TP_ID = '6BD323629A5B4A768A50D4F091BB2952' -- CUST_GL = 'G'"),
#  (521764, '0'),
#  (521975, '0'),
#  (522053, '0'),
#  (522107, '2000'),
#  (522159, '0'),
#  (522229, '2000'),
#  (522286, '1'),
#  (522349, '0'),
#  (522425, '0'),
#  (522480, '0'),
#  (522542, '0'),
#  (522618, '1'),
#  (522708, '0'),
#  (522789, '0'),
#  (522868, '0'),
#  (567913, '1'),
#  (567959, '11'),
#  (568016, '1.0'),
#  (568077, '-1'),
#  (568123, '0'),
#  (568198, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (568290, '#PS_ORA_CONN_SOR.Username#'),
#  (568376, '#PS_ORA_CONN_SOR.Password#'),
#  (568473, '0'),
#  (568533, '11g'),
#  (568599, '0'),
#  (568648, '0'),
#  (568704, '0'),
#  (568784,
#   'select\n'
#   '\tchg.ac_ar_id,\n'
#   '\taxr.EFF_RATE_PCT\tINT_RATE\n'
#   'from TWT_FNC_SVC_AR_ANL_FCT_FA_CHG chg\n'
#   'left join ar_x_rate_tp_rltnp AXR on AXR.ar_x_rate_tp_rltnp_tp_id '
#   "='B1D1E14709EF08BBB38D361A980E4DE1'\n"
#   "    AND AXR.RATE_TP_ID = '2EC90B394FDFF95D4EC063F17BE70B47' \n"
#   "    AND AXR.RATE_CMPT = 'INTEREST_RATE'\n"
#   '\tand AXR.ar_id = chg.AC_AR_ID AND AXR.EFF_DT <= LAST_EFF_DT AND AXR.END_DT '
#   '> LAST_EFF_DT'),
#  (569206, '0'),
#  (569283, 'TWT_FNC_SVC_AR_ANL_FCT_FA_CHG'),
#  (569353, 'ar_x_rate_tp_rltnp'),
#  (569484, 'INT_RATE,EFF_RATE_PCT,axr'),
#  (569552, 'ac_ar_id,ac_ar_id,TWT_FNC_SVC_AR_ANL_FCT_FA_CHG'),
#  (569704, '0'),
#  (569782, '0'),
#  (569836, '2000'),
#  (569888, '0'),
#  (569958, '2000'),
#  (570015, '1'),
#  (570078, '0'),
#  (570154, '0'),
#  (570209, '0'),
#  (570271, '0'),
#  (570347, '1'),
#  (570437, '0'),
#  (570518, '0'),
#  (570597, '0'),
#  (576870, '1'),
#  (576916, '11'),
#  (576973, '1.0'),
#  (577034, '-1'),
#  (577080, '0'),
#  (577155, '#PS_ORA_CONN_SOR.ConnectionString#'),
#  (577247, '#PS_ORA_CONN_SOR.Username#'),
#  (577333, '#PS_ORA_CONN_SOR.Password#'),
#  (577430, '0'),
#  (577490, '11g'),
#  (577556, '0'),
#  (577605, '0'),
#  (577661, '0'),
#  (577741,
#   'SELECT \n'
#   ' CHG.AC_AR_ID                                               AC_AR_ID\n'
#   ",decode(CHG.MUD, 'LN', XIP.IP_ID, CHG.CST_ID)           CST_ID\n"
#   ",CASE WHEN CHG.MUD IN ('OD', 'CARD') THEN '139900'\n"
#   "    WHEN CHG.MUD = 'LN' THEN UDF.UDF_VAL\n"
#   '    ELSE NULL END                                       LOAN_PPS_CODE\n'
#   ',CHG.PD_CODE                                            PD_CODE\n'
#   ',NVL(SALE.IP_ID, CHG.SALE_EMPE_ID)                      RLTNP_OFCR_ID\n'
#   ',IDY.UDF_VAL                                            IDY_CODE\n'
#   ',CHG.ACG_STC_ITM_ID                                     LDGR_ACG_ID\n'
#   ',NVL(XOU.IP_CODE, CHG.RPRG_OU_CODE)                     ADJ_OU_CODE\n'
#   ',CHG.CCY_CODE                                           ADJ_CCY_CODE\n'
#   ',CG.CL_ID                                               CG_SEG\n'
#   ',MSEG.CL_ID                                             MSEG\n'
#   ',EMPE.EMPE_NBR\n'
#   ',CHG.AR_UNQ_ID\n'
#   ",CASE WHEN CHG.MUD IN ('LN', 'OD') THEN 'FCC' ELSE 'SMV' END    "
#   'PD_SRC_STM_CODE\n'
#   ',CHG.CARD_ID                                            PYMT_CARD_ID\n'
#   ',CHG.MUD\n'
#   ',CHG.RPRG_OU_CODE\n'
#   'FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG CHG\n'
#   'LEFT JOIN TMP_AR_X_CST XIP   ON XIP.AR_ID = AC_AR_ID AND XIP.EFF_DT <= '
#   "LAST_EFF_DT AND XIP.END_DT > LAST_EFF_DT --LU CV('AR_X_IP_TP','AR_X_CST')\n"
#   'LEFT JOIN TMP_AR_X_SALE_PERSON SALE ON SALE.AR_ID = AC_AR_ID AND '
#   'SALE.EFF_DT <= LAST_EFF_DT AND SALE.END_DT > LAST_EFF_DT  --LU '
#   "CV('AR_X_IP_TP','AR_X_SALE_PERSON')\n"
#   'LEFT JOIN TMP_AR_X_OU XOU ON XOU.AR_ID = AC_AR_ID AND XOU.EFF_DT <= '
#   "LAST_EFF_DT AND XOU.END_DT > LAST_EFF_DT  --LU CV('AR_X_IP_TP','AR_X_OU')\n"
#   'LEFT JOIN (SELECT UDF.*, CV.CL_CODE FROM AR_X_UDF_RLTNP UDF\n'
#   '            INNER JOIN CV ON UDF.UDF_VAL_ID = CV.CL_ID AND CV.CL_CODE LIKE '
#   "'MUC DICH VAY.%'\n"
#   '            INNER JOIN CV SRC ON SRC.CL_ID = UDF.SRC_STM_ID AND SRC.CL_CODE '
#   "='FCC.CLTB_ACCOUNT_APPS_MASTER'\n"
#   '            ) UDF ON UDF.AR_ID = AC_AR_ID AND UDF.EFF_DT <= LAST_EFF_DT AND '
#   'UDF.END_DT > LAST_EFF_DT\n'
#   'LEFT JOIN (SELECT IDY.* FROM IP_X_UDF_RLTNP IDY\n'
#   '            left join cv on cv.cl_id = idy.UDF_VAL_ID\n'
#   "            WHERE IDY.UDF_ID = '13CDBEEEE9199559A9EF8794322E43E7'\n"
#   '            AND CV.CL_CODE IS NOT NULL) IDY ON IDY.IP_ID = decode(CHG.MUD, '
#   "'LN', XIP.IP_ID, CHG.CST_ID) AND IDY.EFF_DT <= LAST_EFF_DT AND IDY.END_DT > "
#   'LAST_EFF_DT\n'
#   "LEFT JOIN TMP_CL_X_IP_INDUSTRY_TP CG ON decode(CHG.MUD, 'LN', XIP.IP_ID, "
#   'CHG.CST_ID) = CG.IP_ID AND CG.EFF_DT <= LAST_EFF_DT AND CG.END_DT > '
#   "LAST_EFF_DT  --LU CV('CL_X_IP_TP','CL_X_IP_INDUSTRY_TP')\n"
#   "LEFT JOIN TMP_CL_X_IP_MSEG MSEG ON decode(CHG.MUD, 'LN', XIP.IP_ID, "
#   'CHG.CST_ID) = MSEG.IP_ID AND MSEG.EFF_DT <= LAST_EFF_DT AND MSEG.END_DT > '
#   "LAST_EFF_DT  --LU CV('CL_X_IP_TP','CL_X_IP_MSEG')\n"
#   'LEFT JOIN EMPE ON SALE.IP_ID = EMPE.EMPE_ID'),
#  (580437, '0'),
#  (580648, '0'),
#  (580726, '0'),
#  (580780, '2000'),
#  (580832, '0'),
#  (580902, '2000'),
#  (580959, '1'),
#  (581022, '0'),
#  (581098, '0'),
#  (581153, '0'),
#  (581215, '0'),
#  (581291, '1'),
#  (581381, '0'),
#  (581462, '0'),
#  (581541, '0'),
#  (599757, '#PS_ORA_CONN_DMT.ConnectionString#'),
#  (599849, '#PS_ORA_CONN_DMT.Username#'),
#  (599935, '#PS_ORA_CONN_DMT.Password#'),
#  (600032, '0'),
#  (600092, '11g'),
#  (600172, '0'),
#  (600235, '1'),
#  (600300, 'TWT_FNC_SVC_AR_FCT_FA'),
#  (600356, '0'),
#  (600423, '0'),
#  (600502, '3'),
#  (600554, '1'),
#  (600592, '1'),
#  (600677, '1'),
#  (600763, '0'),
#  (600817, '2000'),
#  (600892, '2000'),
#  (600953, '0'),
#  (601023, '0'),
#  (601096, '1'),
#  (601164, '1'),
#  (601258, '0'),
#  (601338, '0'),
#  (601419, '0'),
#  (601498, '0'),
#  (601560, '0')]
# Job Name: PAR_DMT_FNC_SVC_AR_ANL_FCT_FA_Ins
# Job Name: PAR_DMT_FNC_SVC_AR_ANL_FCT_FA_Ins
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_CHG_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_CST_PD_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_LST_DY_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_ANL_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Job Name: PAR_DMT_TWT_FNC_SVC_AR_FCT_FA_TruncIns
# Data has been exported to job_queries.xlsx

# %%
b = """
select
chg.AC_AR_ID
,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_FCY*CHG.ADJ_BAL), CLS_VAL_BAL_FCY*CHG.ADJ_BAL)	CLS_BAL_FCY   
,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_LCY*CHG.ADJ_BAL), CLS_VAL_BAL_LCY*CHG.ADJ_BAL)	CLS_BAL_LCY
,TVR.LQD_AMT_FCY                               			LQD_AMT_FCY
,TVR.LQD_AMT_LCY                       	    			LQD_AMT_LCY
,TVR.DSBR_AMT_TDY_FCY                                   DSBR_AMT_FCY
,TVR.DSBR_AMT_TDY                                      	DSBR_AMT_LCY
,TVR.PREPYMT_AMT	                                    PREPYMT_AMT_FCY
,TVR.PREPYMT_AMT*TVR.EXG_RATE_TO_LCL_CCY	            PREPYMT_AMT_LCY
,TVR.PY_OFF_BFR_DUE_DT_F                              	PY_OFF_BFR_DUE_DT_F
,decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', 
		COALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100))))	    ADJ_FNC_ST_CODE --NHOM NO
,CASE WHEN decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', 
		COALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100)))) <> 'NORM' AND PNP_ARS + INT_ARS > 0 THEN 'THUC_TE' 
      WHEN decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', 
		COALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100)))) <> 'NORM' AND PNP_ARS + INT_ARS = 0 THEN 'THU_THACH'
 END                                        			FNC_ST_TP_CODE
-- Add new luc.luu
,DLQ.PNP_ARS
,DLQ.INT_ARS
,DLQ.NOD_PAST_DUE
,TVR.DSBR_AMT_LTD TOT_DSBR_AMT_FCY
,TVR.INTERIM_INT
,CASE WHEN DLQ.PNP_PAST_DUE_DT <= nvl(DLQ.INT_PAST_DUE_DT,99991231) AND PAST_DUE_F = 1
	  AND  DLQ.PNP_PAST_DUE_DT IS NOT NULL 
	  THEN MONTHS_BETWEEN(Trunc(to_date(#pdate#,'yyyymmdd'),'MONTH'),Trunc(to_date(DLQ.PNP_PAST_DUE_DT,'yyyymmdd'),'MONTH')) 
	  WHEN PAST_DUE_F = 1 AND DLQ.INT_PAST_DUE_DT <= nvl(DLQ.PNP_PAST_DUE_DT,99991231) 
	  AND  DLQ.INT_PAST_DUE_DT IS NOT NULL 
	  THEN MONTHS_BETWEEN(Trunc(to_date(#pdate#,'yyyymmdd'),'MONTH'),Trunc(to_date(DLQ.INT_PAST_DUE_DT,'yyyymmdd'),'MONTH'))
	  ELSE 0 END DLQ_CNT
,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_FCY), CLS_VAL_BAL_FCY) ORIG_CLS_BAL_FCY
,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_LCY), CLS_VAL_BAL_LCY) ORIG_CLS_BAL_LCY
FROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG chg
LEFT JOIN AR_DLQ_SMY DLQ ON ac_AR_ID = DLQ.AR_ID AND DLQ.MSR_PRD_ID = #pDate#
LEFT JOIN TWT_AR_TVR_SMY_DAILY TVR ON ac_AR_ID = TVR.AR_ID AND TVR.MSR_PRD_ID = #pDate#
LEFT JOIN (SELECT ARF.AR_ID, ARF.EFF_DT, ARF.END_DT, CD.CL_CODE
	FROM AR_FNC_ST ARF
	LEFT JOIN CV CD ON CD.CL_ID = ARF.AR_FNC_ST_TP_ID
      WHERE ARF.AR_FNC_ST_SCM_ID = 'FF2F2563FA9BFED792EDC3A35EFDEE92') ARF ON AC_AR_ID = ARF.AR_ID 
	  AND ARF.EFF_DT <= LAST_EFF_DT AND ARF.END_DT > LAST_EFF_DT --LU_CV: 'AR_FNC_ST_SCM', 'USR_DFND_ST']"""
a = remove_comments(b)
a
# Out:
# "\nselect\nchg.AC_AR_ID\n,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_FCY*CHG.ADJ_BAL), CLS_VAL_BAL_FCY*CHG.ADJ_BAL)\tCLS_BAL_FCY   \n,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_LCY*CHG.ADJ_BAL), CLS_VAL_BAL_LCY*CHG.ADJ_BAL)\tCLS_BAL_LCY\n,TVR.LQD_AMT_FCY                               \t\t\tLQD_AMT_FCY\n,TVR.LQD_AMT_LCY                       \t    \t\t\tLQD_AMT_LCY\n,TVR.DSBR_AMT_TDY_FCY                                   DSBR_AMT_FCY\n,TVR.DSBR_AMT_TDY                                      \tDSBR_AMT_LCY\n,TVR.PREPYMT_AMT\t                                    PREPYMT_AMT_FCY\n,TVR.PREPYMT_AMT*TVR.EXG_RATE_TO_LCL_CCY\t            PREPYMT_AMT_LCY\n,TVR.PY_OFF_BFR_DUE_DT_F                              \tPY_OFF_BFR_DUE_DT_F\n,decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', \n\t\tCOALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100))))\t    ADJ_FNC_ST_CODE ,CASE WHEN decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', \n\t\tCOALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100)))) <> 'NORM' AND PNP_ARS + INT_ARS > 0 THEN 'THUC_TE' \n      WHEN decode(tvr.CLS_VAL_BAL_FCY*CHG.ADJ_BAL , 0, 'NORM', \n\t\tCOALESCE(CAST(CHG.LN_FNC_ST_CODE AS VARCHAR2(100)), ARF.CL_CODE, CAST(CHG.CARD_AR_FNC_ST_TP_CODE AS VARCHAR2(100)))) <> 'NORM' AND PNP_ARS + INT_ARS = 0 THEN 'THU_THACH'\n END                                        \t\t\tFNC_ST_TP_CODE\n,DLQ.PNP_ARS\n,DLQ.INT_ARS\n,DLQ.NOD_PAST_DUE\n,TVR.DSBR_AMT_LTD TOT_DSBR_AMT_FCY\n,TVR.INTERIM_INT\n,CASE WHEN DLQ.PNP_PAST_DUE_DT <= nvl(DLQ.INT_PAST_DUE_DT,99991231) AND PAST_DUE_F = 1\n\t  AND  DLQ.PNP_PAST_DUE_DT IS NOT NULL \n\t  THEN MONTHS_BETWEEN(Trunc(to_date(#pdate#,'yyyymmdd'),'MONTH'),Trunc(to_date(DLQ.PNP_PAST_DUE_DT,'yyyymmdd'),'MONTH')) \n\t  WHEN PAST_DUE_F = 1 AND DLQ.INT_PAST_DUE_DT <= nvl(DLQ.PNP_PAST_DUE_DT,99991231) \n\t  AND  DLQ.INT_PAST_DUE_DT IS NOT NULL \n\t  THEN MONTHS_BETWEEN(Trunc(to_date(#pdate#,'yyyymmdd'),'MONTH'),Trunc(to_date(DLQ.INT_PAST_DUE_DT,'yyyymmdd'),'MONTH'))\n\t  ELSE 0 END DLQ_CNT\n,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_FCY), CLS_VAL_BAL_FCY) ORIG_CLS_BAL_FCY\n,decode(CHG.MUD, 'OD', ABS(CLS_VAL_BAL_LCY), CLS_VAL_BAL_LCY) ORIG_CLS_BAL_LCY\nFROM TWT_FNC_SVC_AR_ANL_FCT_FA_CHG chg\nLEFT JOIN AR_DLQ_SMY DLQ ON ac_AR_ID = DLQ.AR_ID AND DLQ.MSR_PRD_ID = #pDate#\nLEFT JOIN TWT_AR_TVR_SMY_DAILY TVR ON ac_AR_ID = TVR.AR_ID AND TVR.MSR_PRD_ID = #pDate#\nLEFT JOIN (SELECT ARF.AR_ID, ARF.EFF_DT, ARF.END_DT, CD.CL_CODE\n\tFROM AR_FNC_ST ARF\n\tLEFT JOIN CV CD ON CD.CL_ID = ARF.AR_FNC_ST_TP_ID\n      WHERE ARF.AR_FNC_ST_SCM_ID = 'FF2F2563FA9BFED792EDC3A35EFDEE92') ARF ON AC_AR_ID = ARF.AR_ID \n\t  AND ARF.EFF_DT <= LAST_EFF_DT AND ARF.END_DT > LAST_EFF_DT "
